# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import GridSearchCV
from sklearn.metrics  import classification_report
from sklearn.svm import SVC
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from collections import Counter
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score
import cv2
from skopt import BayesSearchCV
from skopt.space import Real, Integer, Categorical
from sklearn.base import BaseEstimator
from tqdm import tqdm
from scipy.stats import loguniform, uniform
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics.pairwise import euclidean_distances

# %%
lfw_people = fetch_lfw_people(min_faces_per_person=10,resize=0.4)
#选取样本量量更多的那些人脸，这样会方便训练
lfw_people.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
lfw_data = pd.DataFrame( lfw_people.data)	
lfw_data['species'] = lfw_people.target_names[lfw_people.target]	
lfw_data.head(3)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.358170  0.309804  0.487582  0.701961  0.801307  0.826144  0.856209
# 1  0.231373  0.413072  0.633987  0.789542  0.886275  0.903268  0.900654
# 2  0.341176  0.330719  0.383007  0.420915  0.450980  0.450980  0.443137
#
#           7         8         9  ...      1841      1842      1843      1844  \
# 0  0.882353  0.903268  0.911111  ...  0.202614  0.137255  0.129412  0.122876
# 1  0.896732  0.891503  0.896732  ...  0.054902  0.009150  0.019608  0.014379
# 2  0.427451  0.452288  0.469281  ...  0.194771  0.261438  0.294118  0.504575
#
#        1845      1846      1847      1848      1849          species
# 0  0.138562  0.139869  0.129412  0.149020  0.156863   Jacques Chirac
# 1  0.003922  0.000000  0.000000  0.013072  0.020915     Abdullah Gul
# 2  0.555556  0.554248  0.464052  0.441830  0.503268  Serena Williams
#
# [3 rows x 1851 columns]

# %%
# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape

# for machine learning we use the 2 data directly (as relative pixel
# positions info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# the label to predict is the id of the person
y = lfw_people.target
target_names = lfw_people.target_names
n_classes = target_names.shape[0]

print("Total dataset size:")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features)
print("n_classes: %d" % n_classes)
# Out:
# Total dataset size:
# n_samples: 4324
# n_features: 1850
# n_classes: 158

# %%
plt.imshow(lfw_people.images[5],cmap='gray')
plt.show()

# %% [markdown]
# # Preprocessing:
#
#
# 由于lfw数据集本身已经做了一些数据处理，比如每张图片的尺寸为250X250（shape统一），同时我们调用的数据集也做了灰度化处理来降低复杂度。因此数据预处理上可以做的事情就比较简单，我们可以比较两种数据预处理方法：标准化和归一化。（**可以分别在SVM、CNN上把两种预处理的数据都跑一遍看看结果符不符合预期**）
#
# ***标准化***
#
# $$X=\frac{X-\mu}{\sigma}$$
#
# 作用：使数据均值为 0，方差为 1，适合基于距离的算法（如 SVM、KNN、PCA）。
#
# 但代码结果显示mean $\neq$ 0, $std \neq 1$,原因是PCA、SVM等机器学习模型都遵循scikit-learn 的约定，输入数据 X 必须是形状为 (n_samples, n_features) 的 二维数组，*每一行*是一个样本，*每一列*是一个特征值（如人脸图像的一个像素、一个颜色通道等），而实际代码计算的时候是根据特征值进行标准化（按列），即对于每个元素 $X_{ij}$:
# $$ X_{ij}=\frac{X_{ij}-\mu_{j}}{\sigma_{j}} $$
# 而这里的mean和std都是按行（也就是对于一张图片而言）的，所以会存在mean不等于0等现象。
#
# *标准化的特点*:标准化计算中
#
# $$\mu = \frac{1}{n}\sum_{i=1}^n X, \quad \sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n (X-\mu)^2} $$
#
# 经过标准化后，对于标准差 $\sigma$ 较大的特征值，由于标准差计算中 $\sigma$ 在分母，会实际缩小这些值的差异，让不同图片中区分度很大的地方（可能是噪声）变平滑；同时，对于标准差 $\sigma$ 较小的特征值，标准差计算会放大这些值的特点，也就是对于图像中相同的或者相似的部分，标准化会增强这一特征（比如图片亮处更亮、暗处更暗）。所以整体上，标准化可以使同一特征值的数据更加一致，数据间的距离和差值更小，因此适合基于距离的算法（如 SVM、KNN、PCA）。
#
# ***归一化***
#
# $$X_{norm}=\frac{X-X_{min}}{X_{max}-X_{min}} $$
#
# 作用：将数据线性压缩到固定范围（默认 [0, 1]），适合需要限定输入范围的模型（如神经网络）。
#
# *归一化的特点*：归一化计算中实际上也是对特征进行计算：
# $$X_{norm}[:,j] = \frac{X[:,j]-minX[:,j]}{maxX[:,j]-minX[:,j]}$$
# 这本质上是一种线性变换，数据的分布形状不会产生变化，仅仅是进行缩放和平移（仿射变换），也解释了跑出来的图相较和原图差异不大的现象。
# $$X_{norm}=aX+b,\quad a=\frac{1}{X_{max}-X_{min}},\quad b=\frac{-X_{min}}{X_{max}-X_{min}} $$
#
# 和Batch Normalization一样，缓解梯度消失/爆炸问题，适用于CNN

# %%
# 2. 预处理
# 标准化
scaler_std = StandardScaler()
X_std = scaler_std.fit_transform(X)
# 归一化
scaler_norm = MinMaxScaler()
X_norm = scaler_norm.fit_transform(X)

# 3. 可视化分布
def plot_distribution(X_original, X_std, X_norm, sample_idx=0):
    """绘制三种处理方式的分布对比"""
    plt.figure(figsize=(15, 5))
    
    # 原始数据
    plt.subplot(1, 3, 1)
    plt.hist(X_original[sample_idx], bins=50, color='blue', alpha=0.7)
    plt.title(f"Original Data\nRange: [{X_original[sample_idx].min():.1f}, {X_original[sample_idx].max():.1f}]")
    plt.xlabel("Pixel Value")
    plt.ylabel("Frequency")
    
    # 标准化后
    plt.subplot(1, 3, 2)
    plt.hist(X_std[sample_idx], bins=50, color='red', alpha=0.7)
    plt.title(f"Standardized Data\nMean: {X_std[sample_idx].mean():.2f}, Std: {X_std[sample_idx].std():.2f}")
    plt.xlabel("Scaled Value")
    
    # 归一化后
    plt.subplot(1, 3, 3)
    plt.hist(X_norm[sample_idx], bins=50, color='green', alpha=0.7)
    plt.title(f"Normalized Data\nRange: [{X_norm[sample_idx].min():.2f}, {X_norm[sample_idx].max():.2f}]")
    plt.xlabel("Scaled Value")
    
    plt.tight_layout()
    plt.show()

# 4. 随机选择5个人脸样本对比
for i in np.random.choice(len(X), 5, replace=False):
    print(f"\n=== Sample {i} (Person: {lfw_people.target_names[lfw_people.target[i]]}) ===")
    plot_distribution(X, X_std, X_norm, sample_idx=i)
    
    # 可视化图像对比
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    axes[0].imshow(X[i].reshape(h, w), cmap='gray')
    axes[0].set_title("Original Image")
    axes[1].imshow(X_std[i].reshape(h, w), cmap='gray')
    axes[1].set_title("Standardized Image")
    axes[2].imshow(X_norm[i].reshape(h, w), cmap='gray')
    axes[2].set_title("Normalized Image")
    plt.show()
# Out:
# === Sample 2588 (Person: Pete Sampras) ===
# === Sample 2821 (Person: Naomi Watts) ===
# === Sample 3833 (Person: George W Bush) ===
# === Sample 1900 (Person: Jiang Zemin) ===
# === Sample 1987 (Person: Naomi Watts) ===

# %%
X_original = lfw_people.images  # 原始图像 [n_samples, height, width]
y_original = lfw_people.target  # 标签（虽然预处理不需要，但保留以备后用）
class CLAHEOptimizer(BaseEstimator):
    def __init__(self, 
                 clahe_clip=2.0, 
                 tileGridSize_w=8,  # 改为单独定义宽度和高度
                 tileGridSize_h=8,
                 sharpen_center=5.0, 
                 sigma_s=60, 
                 sigma_r=0.4):
        self.clahe_clip = clahe_clip
        self.tileGridSize_w = tileGridSize_w
        self.tileGridSize_h = tileGridSize_h
        self.sharpen_center = sharpen_center
        self.sigma_s = sigma_s
        self.sigma_r = sigma_r
        
    def fit(self, X, y=None):
        return self
    
    def score(self, X, y=None):
        """计算平均PSNR（越大越好）"""
        total_psnr = 0
        valid_count = 0
        for img in X:
            try:
                enhanced = self.enhance(img)
                psnr = cv2.PSNR((img*255).astype('uint8'), 
                               (enhanced*255).astype('uint8'))
                total_psnr += psnr
                valid_count += 1
            except Exception as e:
                continue
        return total_psnr / valid_count if valid_count > 0 else 0
    
    def enhance(self, img):
        img_uint8 = (img * 255).astype('uint8')
        
        # CLAHE（处理tileGridSize为两个独立参数）
        clahe = cv2.createCLAHE(
            clipLimit=float(self.clahe_clip),
            tileGridSize=(int(self.tileGridSize_w), 
                         int(self.tileGridSize_h))
        )
        enhanced = clahe.apply(img_uint8)
        
        # 锐化
        kernel = np.array([[0,-1,0], 
                          [-1,float(self.sharpen_center),-1], 
                          [0,-1,0]])
        enhanced = cv2.filter2D(enhanced, -1, kernel)
        
        # 保边滤波
        enhanced = cv2.edgePreservingFilter(
            enhanced,
            sigma_s=int(self.sigma_s),
            sigma_r=float(self.sigma_r)
        )
        return enhanced / 255.0

# 参数搜索空间（将tileGridSize拆分为两个独立参数）
param_space = {
    'clahe_clip': Real(1.0, 4.0),
    'tileGridSize_w': Integer(4, 16),  # 宽度范围
    'tileGridSize_h': Integer(4, 16),  # 高度范围
    'sharpen_center': Real(4.0, 8.0),
    'sigma_s': Integer(30, 100),
    'sigma_r': Real(0.1, 0.5)
}

# 运行优化
opt = BayesSearchCV(
    CLAHEOptimizer(),
    param_space,
    n_iter=40,
    cv=2,
    random_state=42,
    n_jobs=1  # 避免并行问题
)

print("开始优化（含tileGridSize）...")
opt.fit(X_original, y=None)  # 显式传入y=None


# 后续处理保持不变
# 输出结果
best_params = {
    'clahe_clip': float(opt.best_params_['clahe_clip']),
    'tileGridSize': (int(opt.best_params_['tileGridSize_w']), 
                     int(opt.best_params_['tileGridSize_h'])),
    'sharpen_center': float(opt.best_params_['sharpen_center']),
    'sigma_s': int(opt.best_params_['sigma_s']),
    'sigma_r': float(opt.best_params_['sigma_r'])
}
print(f"最优参数: {best_params}")
print(f"最佳PSNR: {opt.best_score_:.2f}dB")

# 应用最佳参数
optimizer = CLAHEOptimizer(
    clahe_clip=best_params['clahe_clip'],
    tileGridSize_w=best_params['tileGridSize'][0],
    tileGridSize_h=best_params['tileGridSize'][1],
    sharpen_center=best_params['sharpen_center'],
    sigma_s=best_params['sigma_s'],
    sigma_r=best_params['sigma_r']
)
X_enhanced = np.array([optimizer.enhance(img) for img in tqdm(X_original)])
# 修改预处理代码，处理全部数据

# --- 5. 可视化对比 ---
plt.figure(figsize=(10,5))
for i in range(3):
    plt.subplot(2,3,i+1)
    plt.imshow(X_original[i], cmap='gray', vmin=0, vmax=1)
    plt.title("Original")
    plt.subplot(2,3,i+4)
    plt.imshow(X_enhanced[i], cmap='gray', vmin=0, vmax=1)
    plt.title(f"Enhanced\nPSNR: {cv2.PSNR((X_original[i]*255).astype('uint8'), (X_enhanced[i]*255).astype('uint8')):.1f}dB")
plt.tight_layout()
plt.show()
# Out:
# 开始优化（含tileGridSize）...
# 最优参数: {'clahe_clip': 2.681275345134689, 'tileGridSize': (4, 10), 'sharpen_center': 4.884510661654326, 'sigma_s': 46, 'sigma_r': 0.4953128069202545}
# 最佳PSNR: 18.51dB
# 100%|██████████| 4324/4324 [00:01<00:00, 3212.88it/s]

# %%
# 假设已经得到预处理后的数据 X_enhanced 和对应的标签 y_original
# 如果没有，请先运行前面的预处理代码

# 1. 统计预处理后数据的类别分布
class_counts = Counter(y_original)  # 使用原始标签（预处理不改变标签）

# 2. 按样本量分类
rare_classes = {cls: count for cls, count in class_counts.items() if 10 <= count <= 50}
ma_classes = {cls: count for cls, count in class_counts.items() if count > 50}

# 3. 打印分类信息
print(f"样本量在10-50之间的类别及数量:")
for cls, count in rare_classes.items():
    print(f"类别 {target_names[cls]}: {count} 个样本")
    
print("\n样本量大于50的类别及数量:")
for cls, count in ma_classes.items():
    print(f"类别 {target_names[cls]}: {count} 个样本")

# 4. 准备绘图数据
rclasses = list(rare_classes.keys())
rcounts = list(rare_classes.values())
mclasses = list(ma_classes.keys())
mcounts = list(ma_classes.values())

# 5. 绘制增强后的类别分布图
plt.figure(figsize=(12, 6))

# 绘制条形图
bars1 = plt.bar(range(len(rclasses)), rcounts, color='skyblue', label='中等样本(10-50)')
bars2 = plt.bar(range(len(rclasses), len(rclasses)+len(mclasses)), mcounts, color='orange', label='丰富样本(>50)')

# 添加数值标签
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                '%d' % int(height),
                ha='center', va='bottom')

# 设置x轴标签（显示类别名）
all_classes = rclasses + mclasses
plt.figure(figsize=(10, 5))
plt.bar(rclasses, rcounts, color='skyblue')
plt.bar(mclasses, mcounts, color='orange')

plt.xlabel("classes")
plt.ylabel("sample counts")
plt.title("coubnts of classes ")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# 样本量在10-50之间的类别及数量:
# 类别 Abdullah Gul: 19 个样本
# 类别 Vladimir Putin: 49 个样本
# 类别 James Blake: 14 个样本
# 类别 Silvio Berlusconi: 33 个样本
# 类别 Yoriko Kawaguchi: 14 个样本
# 类别 Mohammed Al-Douri: 15 个样本
# 类别 Bill Simon: 15 个样本
# 类别 Gloria Macapagal Arroyo: 44 个样本
# 类别 Dominique de Villepin: 15 个样本
# 类别 John Kerry: 17 个样本
# 类别 Lindsay Davenport: 22 个样本
# 类别 Alvaro Uribe: 35 个样本
# 类别 Catherine Zeta-Jones: 11 个样本
# 类别 Andy Roddick: 15 个样本
# 类别 Jose Maria Aznar: 23 个样本
# 类别 James Kelly: 11 个样本
# 类别 Atal Bihari Vajpayee: 24 个样本
# 类别 Winona Ryder: 24 个样本
# 类别 Roger Federer: 14 个样本
# 类别 Paul Wolfowitz: 10 个样本
# 类别 Rudolph Giuliani: 26 个样本
# 类别 Richard Gephardt: 11 个样本
# 类别 Laura Bush: 41 个样本
# 类别 Javier Solana: 10 个样本
# 类别 Keanu Reeves: 12 个样本
# 类别 David Nalbandian: 14 个样本
# 类别 George Robertson: 22 个样本
# 类别 Jennifer Capriati: 42 个样本
# 类别 Kim Ryong-sung: 11 个样本
# 类别 John Negroponte: 31 个样本
# 类别 Spencer Abraham: 17 个样本
# 类别 Ricardo Lagos: 27 个样本
# 类别 Jeb Bush: 12 个样本
# 类别 Vicente Fox: 32 个样本
# 类别 Jiri Novak: 11 个样本
# 类别 Luiz Inacio Lula da Silva: 48 个样本
# 类别 Andre Agassi: 36 个样本
# 类别 Hillary Clinton: 14 个样本
# 类别 David Beckham: 31 个样本
# 类别 Richard Myers: 18 个样本
# 类别 Nicanor Duarte Frutos: 11 个样本
# 类别 Michael Jackson: 12 个样本
# 类别 Halle Berry: 16 个样本
# 类别 Walter Mondale: 10 个样本
# 类别 Amelie Mauresmo: 21 个样本
# 类别 Bill Clinton: 29 个样本
# 类别 Pete Sampras: 22 个样本
# 类别 Howard Dean: 12 个样本
# 类别 Jeremy Greenstock: 24 个样本
# 类别 Taha Yassin Ramadan: 15 个样本
# 类别 Michael Schumacher: 18 个样本
# 类别 Meryl Streep: 15 个样本
# 类别 Venus Williams: 17 个样本
# 类别 John Allen Muhammad: 11 个样本
# 类别 Kofi Annan: 32 个样本
# 类别 Carlos Menem: 21 个样本
# 类别 Jennifer Garner: 12 个样本
# 类别 Nestor Kirchner: 37 个样本
# 类别 Megawati Sukarnoputri: 33 个样本
# 类别 Lleyton Hewitt: 41 个样本
# 类别 Tom Ridge: 33 个样本
# 类别 Gordon Brown: 13 个样本
# 类别 John Snow: 17 个样本
# 类别 Gonzalo Sanchez de Lozada: 12 个样本
# 类别 George HW Bush: 13 个样本
# 类别 Ian Thorpe: 10 个样本
# 类别 Arnold Schwarzenegger: 42 个样本
# 类别 Tom Hanks: 10 个样本
# 类别 Recep Tayyip Erdogan: 30 个样本
# 类别 Renee Zellweger: 17 个样本
# 类别 Harrison Ford: 12 个样本
# 类别 Tommy Franks: 16 个样本
# 类别 Roh Moo-hyun: 32 个样本
# 类别 Jean Charest: 17 个样本
# 类别 Guillermo Coria: 30 个样本
# 类别 Hamid Karzai: 22 个样本
# 类别 Hans Blix: 39 个样本
# 类别 Jack Straw: 28 个样本
# 类别 Julianne Moore: 19 个样本
# 类别 Naomi Watts: 22 个样本
# 类别 Tiger Woods: 23 个样本
# 类别 Tom Daschle: 25 个样本
# 类别 Condoleezza Rice: 11 个样本
# 类别 Hu Jintao: 15 个样本
# 类别 Joschka Fischer: 19 个样本
# 类别 Richard Gere: 10 个样本
# 类别 Edmund Stoiber: 13 个样本
# 类别 Queen Elizabeth II: 13 个样本
# 类别 Angelina Jolie: 20 个样本
# 类别 Mahmoud Abbas: 29 个样本
# 类别 Gray Davis: 26 个样本
# 类别 Dick Cheney: 14 个样本
# 类别 Anna Kournikova: 12 个样本
# 类别 Julie Gerberding: 15 个样本
# 类别 Pierce Brosnan: 15 个样本
# 类别 John Paul II: 11 个样本
# 类别 Sergio Vieira De Mello: 11 个样本
# 类别 Adrien Brody: 12 个样本
# 类别 Jennifer Lopez: 21 个样本
# 类别 Joe Lieberman: 13 个样本
# 类别 Lance Armstrong: 18 个样本
# 类别 Mahathir Mohamad: 14 个样本
# 类别 Saddam Hussein: 23 个样本
# 类别 Ari Fleischer: 13 个样本
# 类别 Jiang Zemin: 20 个样本
# 类别 Bill Gates: 17 个样本
# 类别 Ann Veneman: 11 个样本
# 类别 Tom Cruise: 10 个样本
# 类别 Jean-David Levitte: 10 个样本
# 类别 Alejandro Toledo: 39 个样本
# 类别 Pervez Musharraf: 18 个样本
# 类别 Rubens Barrichello: 12 个样本
# 类别 Paul Bremer: 20 个样本
# 类别 Lucio Gutierrez: 13 个样本
# 类别 Juan Carlos Ferrero: 28 个样本
# 类别 Paul Burrell: 11 个样本
# 类别 Britney Spears: 14 个样本
# 类别 Nicole Kidman: 19 个样本
# 类别 Paradorn Srichaphan: 10 个样本
# 类别 Jason Kidd: 10 个样本
# 类别 Fidel Castro: 18 个样本
# 类别 Tim Henman: 19 个样本
# 类别 Jennifer Aniston: 21 个样本
# 类别 John Howard: 19 个样本
# 类别 Carlos Moya: 19 个样本
# 类别 Mark Philippoussis: 11 个样本
# 类别 Kim Clijsters: 14 个样本
# 类别 Tommy Thompson: 10 个样本
# 类别 Trent Lott: 16 个样本
# 类别 Igor Ivanov: 20 个样本
# 类别 John Bolton: 17 个样本
# 类别 Mohammad Khatami: 10 个样本
# 类别 Muhammad Ali: 10 个样本
# 类别 Jacques Rogge: 10 个样本
# 类别 Mike Weir: 11 个样本
# 类别 Tang Jiaxuan: 11 个样本
# 类别 Salma Hayek: 13 个样本
# 类别 Norah Jones: 15 个样本
# 类别 Eduardo Duhalde: 14 个样本
# 类别 Nancy Pelosi: 15 个样本
# 类别 Bill McBride: 10 个样本
# 类别 Michael Bloomberg: 20 个样本
# 类别 Wen Jiabao: 13 个样本
# 类别 Jackie Chan: 13 个样本
# 类别 Sergey Lavrov: 11 个样本
# 类别 Charles Moose: 13 个样本
#
# 样本量大于50的类别及数量:
# 类别 Jacques Chirac: 52 个样本
# 类别 Serena Williams: 52 个样本
# 类别 Colin Powell: 236 个样本
# 类别 Ariel Sharon: 77 个样本
# 类别 Gerhard Schroeder: 109 个样本
# 类别 George W Bush: 530 个样本
# 类别 Tony Blair: 144 个样本
# 类别 Junichiro Koizumi: 60 个样本
# 类别 Jean Chretien: 55 个样本
# 类别 Hugo Chavez: 71 个样本
# 类别 Donald Rumsfeld: 121 个样本
# 类别 John Ashcroft: 53 个样本

# %%
class_counts = Counter(y_original)

print("类别分布:", class_counts)
# Out:
# 类别分布: Counter({35: 530, 23: 236, 149: 144, 29: 121, 36: 109, 11: 77, 49: 71, 85: 60, 61: 55, 73: 53, 54: 52, 134: 52, 153: 49, 95: 48, 37: 44, 65: 42, 12: 42, 91: 41, 93: 41, 44: 39, 2: 39, 110: 37, 5: 36, 3: 35, 137: 33, 99: 33, 146: 33, 152: 32, 89: 32, 129: 32, 77: 31, 25: 31, 122: 30, 41: 30, 14: 29, 97: 29, 52: 28, 82: 28, 124: 27, 131: 26, 40: 26, 144: 25, 13: 24, 156: 24, 68: 24, 81: 23, 141: 23, 132: 23, 92: 22, 34: 22, 119: 22, 43: 22, 109: 22, 4: 21, 19: 21, 67: 21, 64: 21, 7: 20, 69: 20, 115: 20, 51: 20, 101: 20, 0: 19, 83: 19, 80: 19, 112: 19, 142: 19, 75: 19, 20: 19, 127: 18, 103: 18, 90: 18, 118: 18, 32: 18, 76: 17, 138: 17, 151: 17, 79: 17, 123: 17, 60: 17, 15: 17, 74: 17, 42: 16, 147: 16, 150: 16, 106: 15, 17: 15, 28: 15, 6: 15, 139: 15, 100: 15, 48: 15, 84: 15, 120: 15, 113: 15, 108: 15, 56: 14, 157: 14, 128: 14, 26: 14, 46: 14, 27: 14, 96: 14, 18: 14, 87: 14, 31: 14, 39: 13, 33: 13, 30: 13, 121: 13, 71: 13, 10: 13, 94: 13, 133: 13, 155: 13, 53: 13, 22: 13, 86: 12, 63: 12, 102: 12, 47: 12, 66: 12, 38: 12, 45: 12, 9: 12, 1: 12, 130: 12, 21: 11, 57: 11, 125: 11, 88: 11, 70: 11, 111: 11, 72: 11, 24: 11, 78: 11, 136: 11, 8: 11, 116: 11, 98: 11, 104: 11, 140: 11, 135: 11, 117: 10, 59: 10, 154: 10, 50: 10, 145: 10, 126: 10, 143: 10, 62: 10, 114: 10, 58: 10, 148: 10, 105: 10, 107: 10, 55: 10, 16: 10})

# %%
rare_classes = {cls: count for cls, count in class_counts.items() if 10 <= count <= 50}
ma_classes = {cls: count for cls, count in class_counts.items() if count > 50}
print(f"样本量在10-50之间的类别及数量:")
for cls, count in rare_classes.items():
    print(f"类别 {target_names[cls]}: {count} 个样本")
print("样本量大于50的类别及数量:")
for cls, count in ma_classes.items():
    print(f"类别 {target_names[cls]}: {count} 个样本")


# 提取类别和样本数
rclasses = list(rare_classes.keys())
rcounts = list(rare_classes.values())
mclasses= list(ma_classes.keys())
mcounts = list(ma_classes.values())

# 绘制条形图
plt.figure(figsize=(10, 5))
plt.bar(rclasses, rcounts, color='skyblue')
plt.bar(mclasses, mcounts, color='orange')

plt.xlabel("classes")
plt.ylabel("sample counts")
plt.title("counts of classes ")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# 样本量在10-50之间的类别及数量:
# 类别 Abdullah Gul: 19 个样本
# 类别 Vladimir Putin: 49 个样本
# 类别 James Blake: 14 个样本
# 类别 Silvio Berlusconi: 33 个样本
# 类别 Yoriko Kawaguchi: 14 个样本
# 类别 Mohammed Al-Douri: 15 个样本
# 类别 Bill Simon: 15 个样本
# 类别 Gloria Macapagal Arroyo: 44 个样本
# 类别 Dominique de Villepin: 15 个样本
# 类别 John Kerry: 17 个样本
# 类别 Lindsay Davenport: 22 个样本
# 类别 Alvaro Uribe: 35 个样本
# 类别 Catherine Zeta-Jones: 11 个样本
# 类别 Andy Roddick: 15 个样本
# 类别 Jose Maria Aznar: 23 个样本
# 类别 James Kelly: 11 个样本
# 类别 Atal Bihari Vajpayee: 24 个样本
# 类别 Winona Ryder: 24 个样本
# 类别 Roger Federer: 14 个样本
# 类别 Paul Wolfowitz: 10 个样本
# 类别 Rudolph Giuliani: 26 个样本
# 类别 Richard Gephardt: 11 个样本
# 类别 Laura Bush: 41 个样本
# 类别 Javier Solana: 10 个样本
# 类别 Keanu Reeves: 12 个样本
# 类别 David Nalbandian: 14 个样本
# 类别 George Robertson: 22 个样本
# 类别 Jennifer Capriati: 42 个样本
# 类别 Kim Ryong-sung: 11 个样本
# 类别 John Negroponte: 31 个样本
# 类别 Spencer Abraham: 17 个样本
# 类别 Ricardo Lagos: 27 个样本
# 类别 Jeb Bush: 12 个样本
# 类别 Vicente Fox: 32 个样本
# 类别 Jiri Novak: 11 个样本
# 类别 Luiz Inacio Lula da Silva: 48 个样本
# 类别 Andre Agassi: 36 个样本
# 类别 Hillary Clinton: 14 个样本
# 类别 David Beckham: 31 个样本
# 类别 Richard Myers: 18 个样本
# 类别 Nicanor Duarte Frutos: 11 个样本
# 类别 Michael Jackson: 12 个样本
# 类别 Halle Berry: 16 个样本
# 类别 Walter Mondale: 10 个样本
# 类别 Amelie Mauresmo: 21 个样本
# 类别 Bill Clinton: 29 个样本
# 类别 Pete Sampras: 22 个样本
# 类别 Howard Dean: 12 个样本
# 类别 Jeremy Greenstock: 24 个样本
# 类别 Taha Yassin Ramadan: 15 个样本
# 类别 Michael Schumacher: 18 个样本
# 类别 Meryl Streep: 15 个样本
# 类别 Venus Williams: 17 个样本
# 类别 John Allen Muhammad: 11 个样本
# 类别 Kofi Annan: 32 个样本
# 类别 Carlos Menem: 21 个样本
# 类别 Jennifer Garner: 12 个样本
# 类别 Nestor Kirchner: 37 个样本
# 类别 Megawati Sukarnoputri: 33 个样本
# 类别 Lleyton Hewitt: 41 个样本
# 类别 Tom Ridge: 33 个样本
# 类别 Gordon Brown: 13 个样本
# 类别 John Snow: 17 个样本
# 类别 Gonzalo Sanchez de Lozada: 12 个样本
# 类别 George HW Bush: 13 个样本
# 类别 Ian Thorpe: 10 个样本
# 类别 Arnold Schwarzenegger: 42 个样本
# 类别 Tom Hanks: 10 个样本
# 类别 Recep Tayyip Erdogan: 30 个样本
# 类别 Renee Zellweger: 17 个样本
# 类别 Harrison Ford: 12 个样本
# 类别 Tommy Franks: 16 个样本
# 类别 Roh Moo-hyun: 32 个样本
# 类别 Jean Charest: 17 个样本
# 类别 Guillermo Coria: 30 个样本
# 类别 Hamid Karzai: 22 个样本
# 类别 Hans Blix: 39 个样本
# 类别 Jack Straw: 28 个样本
# 类别 Julianne Moore: 19 个样本
# 类别 Naomi Watts: 22 个样本
# 类别 Tiger Woods: 23 个样本
# 类别 Tom Daschle: 25 个样本
# 类别 Condoleezza Rice: 11 个样本
# 类别 Hu Jintao: 15 个样本
# 类别 Joschka Fischer: 19 个样本
# 类别 Richard Gere: 10 个样本
# 类别 Edmund Stoiber: 13 个样本
# 类别 Queen Elizabeth II: 13 个样本
# 类别 Angelina Jolie: 20 个样本
# 类别 Mahmoud Abbas: 29 个样本
# 类别 Gray Davis: 26 个样本
# 类别 Dick Cheney: 14 个样本
# 类别 Anna Kournikova: 12 个样本
# 类别 Julie Gerberding: 15 个样本
# 类别 Pierce Brosnan: 15 个样本
# 类别 John Paul II: 11 个样本
# 类别 Sergio Vieira De Mello: 11 个样本
# 类别 Adrien Brody: 12 个样本
# 类别 Jennifer Lopez: 21 个样本
# 类别 Joe Lieberman: 13 个样本
# 类别 Lance Armstrong: 18 个样本
# 类别 Mahathir Mohamad: 14 个样本
# 类别 Saddam Hussein: 23 个样本
# 类别 Ari Fleischer: 13 个样本
# 类别 Jiang Zemin: 20 个样本
# 类别 Bill Gates: 17 个样本
# 类别 Ann Veneman: 11 个样本
# 类别 Tom Cruise: 10 个样本
# 类别 Jean-David Levitte: 10 个样本
# 类别 Alejandro Toledo: 39 个样本
# 类别 Pervez Musharraf: 18 个样本
# 类别 Rubens Barrichello: 12 个样本
# 类别 Paul Bremer: 20 个样本
# 类别 Lucio Gutierrez: 13 个样本
# 类别 Juan Carlos Ferrero: 28 个样本
# 类别 Paul Burrell: 11 个样本
# 类别 Britney Spears: 14 个样本
# 类别 Nicole Kidman: 19 个样本
# 类别 Paradorn Srichaphan: 10 个样本
# 类别 Jason Kidd: 10 个样本
# 类别 Fidel Castro: 18 个样本
# 类别 Tim Henman: 19 个样本
# 类别 Jennifer Aniston: 21 个样本
# 类别 John Howard: 19 个样本
# 类别 Carlos Moya: 19 个样本
# 类别 Mark Philippoussis: 11 个样本
# 类别 Kim Clijsters: 14 个样本
# 类别 Tommy Thompson: 10 个样本
# 类别 Trent Lott: 16 个样本
# 类别 Igor Ivanov: 20 个样本
# 类别 John Bolton: 17 个样本
# 类别 Mohammad Khatami: 10 个样本
# 类别 Muhammad Ali: 10 个样本
# 类别 Jacques Rogge: 10 个样本
# 类别 Mike Weir: 11 个样本
# 类别 Tang Jiaxuan: 11 个样本
# 类别 Salma Hayek: 13 个样本
# 类别 Norah Jones: 15 个样本
# 类别 Eduardo Duhalde: 14 个样本
# 类别 Nancy Pelosi: 15 个样本
# 类别 Bill McBride: 10 个样本
# 类别 Michael Bloomberg: 20 个样本
# 类别 Wen Jiabao: 13 个样本
# 类别 Jackie Chan: 13 个样本
# 类别 Sergey Lavrov: 11 个样本
# 类别 Charles Moose: 13 个样本
# 样本量大于50的类别及数量:
# 类别 Jacques Chirac: 52 个样本
# 类别 Serena Williams: 52 个样本
# 类别 Colin Powell: 236 个样本
# 类别 Ariel Sharon: 77 个样本
# 类别 Gerhard Schroeder: 109 个样本
# 类别 George W Bush: 530 个样本
# 类别 Tony Blair: 144 个样本
# 类别 Junichiro Koizumi: 60 个样本
# 类别 Jean Chretien: 55 个样本
# 类别 Hugo Chavez: 71 个样本
# 类别 Donald Rumsfeld: 121 个样本
# 类别 John Ashcroft: 53 个样本

# %%
# 1. 展平预处理后的图像数据以匹配原始格式 (50,37) -> 1850
X_enhanced_flat = X_enhanced.reshape(len(X_enhanced), -1)  # (n_samples, 1850)

# 2. 按样本量分类（保持原始分类标准）
class_counts = Counter(y_original)
rare_classes = {cls: count for cls, count in class_counts.items() if 10 <= count <= 50}
ma_classes = {cls: count for cls, count in class_counts.items() if count > 50}

rclasses = list(rare_classes.keys())
mclasses = list(ma_classes.keys())

# 3. 初始化存储容器
X_rare, y_rare, X_rare_train, y_rare_train, X_rare_test, y_rare_test = [], [], [], [], [], []
X_ma, y_ma, X_ma_train, y_ma_train, X_ma_test, y_ma_test = [], [], [], [], [], []

# 4. 处理中等样本量类别(10-50)
for cls in rclasses:
    cls_id = np.where(y_original == cls)[0]
    X_rare.append(X_enhanced_flat[cls_id])  # 使用展平后的数据
    y_rare.append(y_original[cls_id])

X_rare = np.concatenate(X_rare)
y_rare = np.concatenate(y_rare)
X_rare_train, X_rare_test, y_rare_train, y_rare_test = train_test_split(
    X_rare, y_rare, test_size=0.25, random_state=42, stratify=y_rare
)

# 5. 处理大样本量类别(>50)
for cls in mclasses:
    cls_id = np.where(y_original == cls)[0]
    X_ma.append(X_enhanced_flat[cls_id])  # 使用展平后的数据
    y_ma.append(y_original[cls_id])

X_ma = np.concatenate(X_ma)
y_ma = np.concatenate(y_ma)
X_ma_train, X_ma_test, y_ma_train, y_ma_test = train_test_split(
    X_ma, y_ma, test_size=0.25, random_state=42, stratify=y_ma
)

# 6. 打印形状信息（应与原始输出完全一致）
print("Rare classes train and test sets:")
print("X_rare shape:", X_rare.shape)
print("y_rare shape:", y_rare.shape)
print("X_ma shape:", X_ma.shape)
print("y_ma shape:", y_ma.shape)
print("\nTraining sets:")
print("X_rare_train shape:", X_rare_train.shape)
print("Unique classes in y_rare_train:", len(np.unique(y_rare_train)))
print("X_ma_train shape:", X_ma_train.shape)
print("Unique classes in y_ma_train:", len(np.unique(y_ma_train)))
print("\nTest sets:")
print("X_rare_test shape:", X_rare_test.shape)
print("Unique classes in y_rare_test:", len(np.unique(y_rare_test)))
print("X_ma_test shape:", X_ma_test.shape)
print("Unique classes in y_ma_test:", len(np.unique(y_ma_test)))
print("\nLength of target_names:", len(lfw_people.target_names))

# 7. 验证数据一致性
assert X_rare.shape == (2764, 1850), "X_rare形状不匹配"
assert X_ma.shape == (1560, 1850), "X_ma形状不匹配"
assert len(np.unique(y_rare_train)) == 146, "y_rare_train类别数不匹配"
assert len(np.unique(y_ma_train)) == 12, "y_ma_train类别数不匹配"
# Out:
# Rare classes train and test sets:
# X_rare shape: (2764, 1850)
# y_rare shape: (2764,)
# X_ma shape: (1560, 1850)
# y_ma shape: (1560,)
#
# Training sets:
# X_rare_train shape: (2073, 1850)
# Unique classes in y_rare_train: 146
# X_ma_train shape: (1170, 1850)
# Unique classes in y_ma_train: 12
#
# Test sets:
# X_rare_test shape: (691, 1850)
# Unique classes in y_rare_test: 146
# X_ma_test shape: (390, 1850)
# Unique classes in y_ma_test: 12
#
# Length of target_names: 158

# %%
n_samples_to_show = 5  # 每个类别显示5张图片
max_classes_to_show = 3  # 最多显示3个稀有类别

# 获取要展示的类别
rare_class_items = list(rare_classes.items())[:max_classes_to_show]

# 设置画布尺寸：增加高度以容纳两行图像
fig, axes = plt.subplots(len(rare_class_items)*2, n_samples_to_show, 
                        figsize=(n_samples_to_show * 3, len(rare_class_items) * 6))
fig.suptitle("Original vs Preprocessed Images (Rare Classes)", fontsize=20)

for i, (cls, count) in enumerate(rare_class_items):
    cls_indices = np.where(y == cls)[0]
    selected_indices = np.random.choice(cls_indices, size=min(n_samples_to_show, len(cls_indices)), replace=False)
    
    for j in range(n_samples_to_show):
        # 原始图像行 (第i*2行)
        ax_original = axes[i*2][j] if len(rare_class_items) > 1 else axes[j]
        # 预处理图像行 (第i*2+1行)
        ax_processed = axes[i*2+1][j] if len(rare_class_items) > 1 else axes[j + n_samples_to_show]
        
        if j < len(selected_indices):
            idx = selected_indices[j]
            
            # 显示原始图像
            ax_original.imshow(lfw_people.images[idx], cmap='gray')
            ax_original.set_title(f"Original\n{target_names[cls]}", fontsize=10)
            ax_original.axis('off')
            
            # 显示预处理图像
            # 处理不同维度的预处理数据
            if X_enhanced[idx].ndim == 1:  # 展平的数据
                img_processed = X_enhanced[idx].reshape(lfw_people.images.shape[1:])
            elif X_enhanced[idx].ndim == 3 and X_enhanced[idx].shape[-1] == 1:  # 单通道
                img_processed = X_enhanced[idx].squeeze()
            else:
                img_processed = X_enhanced[idx]
                
            ax_processed.imshow(img_processed, cmap='gray')
            ax_processed.set_title(f"Preprocessed\nSample {j+1}", fontsize=10)
            ax_processed.axis('off')
        else:
            # 隐藏多余子图
            ax_original.axis('off')
            ax_processed.axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # 留出标题位置
plt.show()

# %%
ma_class_items = list(ma_classes.items())[:max_classes_to_show]

# 设置画布尺寸：增加高度以容纳两行图像
fig, axes = plt.subplots(len(ma_class_items)*2, n_samples_to_show, 
                        figsize=(n_samples_to_show * 3, len(ma_class_items) * 6))
fig.suptitle("Original vs Preprocessed Images (MA Classes >30 samples)", fontsize=20)

for i, (cls, count) in enumerate(ma_class_items):
    cls_indices = np.where(y == cls)[0]
    selected_indices = np.random.choice(cls_indices, size=min(n_samples_to_show, len(cls_indices)), replace=False)
    
    for j in range(n_samples_to_show):
        # 原始图像行 (第i*2行)
        ax_original = axes[i*2][j] if len(ma_class_items) > 1 else axes[j]
        # 预处理图像行 (第i*2+1行)
        ax_processed = axes[i*2+1][j] if len(ma_class_items) > 1 else axes[j + n_samples_to_show]
        
        if j < len(selected_indices):
            idx = selected_indices[j]
            
            # 显示原始图像
            ax_original.imshow(lfw_people.images[idx], cmap='gray')
            ax_original.set_title(f"Original\n{target_names[cls]}", fontsize=10)
            ax_original.axis('off')
            
            # 显示预处理图像
            # 处理不同维度的预处理数据
            if X_enhanced[idx].ndim == 1:  # 展平的数据
                img_processed = X_enhanced[idx].reshape(lfw_people.images.shape[1:])
            elif X_enhanced[idx].ndim == 3 and X_enhanced[idx].shape[-1] == 1:  # 单通道
                img_processed = X_enhanced[idx].squeeze()
            else:
                img_processed = X_enhanced[idx]
                
            ax_processed.imshow(img_processed, cmap='gray')
            ax_processed.set_title(f"Preprocessed\nSample {j+1}", fontsize=10)
            ax_processed.axis('off')
        else:
            # 隐藏多余子图
            ax_original.axis('off')
            ax_processed.axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # 留出标题位置
plt.show()

# %%
ma_class_items = list(ma_classes.items())[:max_classes_to_show]

# 设置画布尺寸：每个样本占用两行（原始+预处理）
fig, axes = plt.subplots(len(ma_class_items)*2, n_samples_to_show, 
                        figsize=(n_samples_to_show * 3, len(ma_class_items) * 6))
fig.suptitle("Original vs Preprocessed Images (MA Classes >30 samples)", fontsize=16)

for i, (cls, count) in enumerate(ma_class_items):
    cls_indices = np.where(y == cls)[0]
    selected_indices = np.random.choice(cls_indices, size=min(n_samples_to_show, len(cls_indices)), replace=False)
    
    for j in range(n_samples_to_show):
        # 原始图像行 (第i*2行)
        ax_original = axes[i*2][j] if len(ma_class_items) > 1 else axes[j]
        # 预处理图像行 (第i*2+1行)
        ax_processed = axes[i*2+1][j] if len(ma_class_items) > 1 else axes[j + n_samples_to_show]
        
        if j < len(selected_indices):
            idx = selected_indices[j]
            
            # 显示原始图像（保持原始尺寸）
            ax_original.imshow(lfw_people.images[idx], cmap='gray')
            ax_original.set_title(f"Original: {target_names[cls]}\nSample {j+1}", fontsize=10)
            ax_original.axis('off')
            
            # 显示预处理图像（确保与原始图像相同尺寸）
            if X_enhanced[idx].ndim == 1:  # 如果是展平的数据
                processed_img = X_enhanced[idx].reshape(lfw_people.images.shape[1:])
            else:
                processed_img = X_enhanced[idx]
                
            ax_processed.imshow(processed_img, cmap='gray')
            ax_processed.set_title(f"Preprocessed", fontsize=10)
            ax_processed.axis('off')
        else:
            # 隐藏多余子图
            ax_original.axis('off')
            ax_processed.axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # 留出标题位置
plt.show()

# %%
#标准化操作
scaler = StandardScaler()
X_rare_train = scaler.fit_transform(X_rare_train)
X_rare_test = scaler.transform(X_rare_test)
X_ma_train = scaler.fit_transform(X_ma_train)
X_ma_test = scaler.transform(X_ma_test)

# %% [markdown]
# ## Using SVC only

# %%
model = SVC(kernel='rbf',class_weight='balanced')
model.fit(X_rare_train,y_rare_train)
# Out:
# SVC(class_weight='balanced')

# %%
predictions=model.predict(X_rare_test)

labels_in_use = np.unique(np.concatenate([y_rare_test, predictions]))
target_names_filtered = [lfw_people.target_names[i] for i in labels_in_use]

# 打印分类报告
print(classification_report(y_rare_test, predictions,
                            labels=labels_in_use,
                            target_names=target_names_filtered,
                            zero_division=0))
# Out:
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       0.00      0.00      0.00         5
#              Adrien Brody       0.00      0.00      0.00         3
#          Alejandro Toledo       0.10      0.50      0.17        10
#              Alvaro Uribe       0.36      0.56      0.43         9
#           Amelie Mauresmo       1.00      0.20      0.33         5
#              Andre Agassi       0.15      0.22      0.18         9
#              Andy Roddick       0.50      0.25      0.33         4
#            Angelina Jolie       0.20      0.40      0.27         5
#               Ann Veneman       0.00      0.00      0.00         3
#           Anna Kournikova       0.00      0.00      0.00         3
#             Ari Fleischer       1.00      0.33      0.50         3
#     Arnold Schwarzenegger       0.06      0.20      0.09        10
#      Atal Bihari Vajpayee       0.50      0.50      0.50         6
#              Bill Clinton       0.33      0.43      0.38         7
#                Bill Gates       1.00      0.25      0.40         4
#              Bill McBride       0.00      0.00      0.00         3
#                Bill Simon       1.00      0.25      0.40         4
#            Britney Spears       1.00      0.25      0.40         4
#              Carlos Menem       0.00      0.00      0.00         5
#               Carlos Moya       1.00      0.20      0.33         5
#      Catherine Zeta-Jones       1.00      0.33      0.50         3
#             Charles Moose       1.00      0.33      0.50         3
#          Condoleezza Rice       0.50      0.33      0.40         3
#             David Beckham       0.60      0.38      0.46         8
#          David Nalbandian       0.00      0.00      0.00         4
#               Dick Cheney       0.00      0.00      0.00         3
#     Dominique de Villepin       0.00      0.00      0.00         4
#            Edmund Stoiber       0.00      0.00      0.00         3
#           Eduardo Duhalde       0.33      0.33      0.33         3
#              Fidel Castro       0.00      0.00      0.00         5
#            George HW Bush       0.00      0.00      0.00         3
#          George Robertson       0.23      0.60      0.33         5
#   Gloria Macapagal Arroyo       0.53      0.73      0.62        11
# Gonzalo Sanchez de Lozada       0.00      0.00      0.00         3
#              Gordon Brown       0.00      0.00      0.00         3
#                Gray Davis       0.20      0.29      0.24         7
#           Guillermo Coria       0.19      0.71      0.29         7
#               Halle Berry       0.67      0.50      0.57         4
#              Hamid Karzai       0.29      0.40      0.33         5
#                 Hans Blix       0.18      0.20      0.19        10
#             Harrison Ford       0.67      0.67      0.67         3
#           Hillary Clinton       1.00      0.33      0.50         3
#               Howard Dean       0.00      0.00      0.00         3
#                 Hu Jintao       1.00      0.50      0.67         4
#                Ian Thorpe       0.00      0.00      0.00         2
#               Igor Ivanov       0.10      0.20      0.13         5
#                Jack Straw       0.11      0.57      0.19         7
#               Jackie Chan       0.00      0.00      0.00         3
#             Jacques Rogge       0.00      0.00      0.00         3
#               James Blake       1.00      0.75      0.86         4
#               James Kelly       0.00      0.00      0.00         3
#                Jason Kidd       0.00      0.00      0.00         2
#             Javier Solana       0.00      0.00      0.00         2
#              Jean Charest       0.27      0.75      0.40         4
#        Jean-David Levitte       1.00      0.33      0.50         3
#                  Jeb Bush       0.00      0.00      0.00         3
#          Jennifer Aniston       0.75      0.60      0.67         5
#         Jennifer Capriati       0.12      0.50      0.20        10
#           Jennifer Garner       0.00      0.00      0.00         3
#            Jennifer Lopez       0.20      0.40      0.27         5
#         Jeremy Greenstock       1.00      0.50      0.67         6
#               Jiang Zemin       0.50      0.20      0.29         5
#                Jiri Novak       1.00      0.33      0.50         3
#             Joe Lieberman       0.00      0.00      0.00         3
#       John Allen Muhammad       1.00      1.00      1.00         3
#               John Bolton       1.00      0.25      0.40         4
#               John Howard       0.00      0.00      0.00         5
#                John Kerry       0.80      1.00      0.89         4
#           John Negroponte       0.27      0.38      0.32         8
#              John Paul II       1.00      0.33      0.50         3
#                 John Snow       0.00      0.00      0.00         4
#           Joschka Fischer       0.67      0.40      0.50         5
#          Jose Maria Aznar       0.00      0.00      0.00         6
#       Juan Carlos Ferrero       0.50      0.57      0.53         7
#            Julianne Moore       0.10      0.20      0.13         5
#          Julie Gerberding       1.00      0.25      0.40         4
#              Keanu Reeves       0.00      0.00      0.00         3
#             Kim Clijsters       0.50      0.25      0.33         4
#            Kim Ryong-sung       0.00      0.00      0.00         3
#                Kofi Annan       0.43      0.75      0.55         8
#           Lance Armstrong       0.00      0.00      0.00         5
#                Laura Bush       0.35      0.70      0.47        10
#         Lindsay Davenport       0.67      0.40      0.50         5
#            Lleyton Hewitt       0.29      0.60      0.39        10
#           Lucio Gutierrez       0.00      0.00      0.00         3
# Luiz Inacio Lula da Silva       0.50      0.58      0.54        12
#          Mahathir Mohamad       0.00      0.00      0.00         3
#             Mahmoud Abbas       0.25      0.29      0.27         7
#        Mark Philippoussis       1.00      0.33      0.50         3
#     Megawati Sukarnoputri       0.40      0.50      0.44         8
#              Meryl Streep       0.33      0.50      0.40         4
#         Michael Bloomberg       0.00      0.00      0.00         5
#           Michael Jackson       1.00      0.67      0.80         3
#        Michael Schumacher       0.00      0.00      0.00         4
#                 Mike Weir       1.00      0.33      0.50         3
#          Mohammad Khatami       0.00      0.00      0.00         3
#         Mohammed Al-Douri       0.00      0.00      0.00         4
#              Muhammad Ali       0.00      0.00      0.00         3
#              Nancy Pelosi       0.00      0.00      0.00         4
#               Naomi Watts       0.60      0.60      0.60         5
#           Nestor Kirchner       0.07      0.22      0.11         9
#     Nicanor Duarte Frutos       0.00      0.00      0.00         3
#             Nicole Kidman       0.50      0.20      0.29         5
#               Norah Jones       0.00      0.00      0.00         4
#       Paradorn Srichaphan       1.00      0.50      0.67         2
#               Paul Bremer       1.00      0.20      0.33         5
#              Paul Burrell       1.00      0.67      0.80         3
#            Paul Wolfowitz       0.00      0.00      0.00         2
#          Pervez Musharraf       0.00      0.00      0.00         4
#              Pete Sampras       0.33      0.17      0.22         6
#            Pierce Brosnan       0.00      0.00      0.00         4
#        Queen Elizabeth II       0.00      0.00      0.00         3
#      Recep Tayyip Erdogan       0.50      0.14      0.22         7
#           Renee Zellweger       0.40      0.50      0.44         4
#             Ricardo Lagos       0.29      0.29      0.29         7
#          Richard Gephardt       0.00      0.00      0.00         3
#              Richard Gere       0.00      0.00      0.00         2
#             Richard Myers       0.00      0.00      0.00         4
#             Roger Federer       0.00      0.00      0.00         3
#              Roh Moo-hyun       1.00      0.88      0.93         8
#        Rubens Barrichello       0.00      0.00      0.00         3
#          Rudolph Giuliani       0.00      0.00      0.00         7
#            Saddam Hussein       0.75      0.50      0.60         6
#               Salma Hayek       0.00      0.00      0.00         3
#             Sergey Lavrov       0.00      0.00      0.00         3
#    Sergio Vieira De Mello       0.00      0.00      0.00         3
#         Silvio Berlusconi       0.00      0.00      0.00         8
#           Spencer Abraham       0.10      0.25      0.14         4
#       Taha Yassin Ramadan       0.50      0.25      0.33         4
#              Tang Jiaxuan       0.00      0.00      0.00         3
#               Tiger Woods       0.25      0.17      0.20         6
#                Tim Henman       0.17      0.20      0.18         5
#                Tom Cruise       0.00      0.00      0.00         3
#               Tom Daschle       0.00      0.00      0.00         6
#                 Tom Hanks       0.00      0.00      0.00         3
#                 Tom Ridge       0.20      0.25      0.22         8
#              Tommy Franks       0.00      0.00      0.00         4
#            Tommy Thompson       0.00      0.00      0.00         3
#                Trent Lott       1.00      0.50      0.67         4
#            Venus Williams       0.40      0.50      0.44         4
#               Vicente Fox       0.60      0.38      0.46         8
#            Vladimir Putin       0.14      0.25      0.18        12
#            Walter Mondale       0.00      0.00      0.00         3
#                Wen Jiabao       0.00      0.00      0.00         3
#              Winona Ryder       0.33      0.33      0.33         6
#          Yoriko Kawaguchi       0.00      0.00      0.00         3
#
#                  accuracy                           0.29       691
#                 macro avg       0.32      0.24      0.24       691
#              weighted avg       0.33      0.29      0.27       691

# %%
model = SVC(kernel='rbf',class_weight='balanced')
model.fit(X_ma_train,y_ma_train)
predictions=model.predict(X_ma_test)

labels_in_use = np.unique(np.concatenate([y_ma_test, predictions]))
target_names_filtered = [lfw_people.target_names[i] for i in labels_in_use]

# 打印分类报告
print(classification_report(y_ma_test, predictions,
                            labels=labels_in_use,
                            target_names=target_names_filtered,
                            zero_division=0))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.90      0.47      0.62        19
#      Colin Powell       0.53      0.88      0.66        59
#   Donald Rumsfeld       0.66      0.83      0.74        30
#     George W Bush       0.81      0.80      0.80       133
# Gerhard Schroeder       0.51      0.74      0.61        27
#       Hugo Chavez       0.78      0.39      0.52        18
#    Jacques Chirac       0.75      0.23      0.35        13
#     Jean Chretien       0.75      0.21      0.33        14
#     John Ashcroft       1.00      0.38      0.56        13
# Junichiro Koizumi       1.00      0.67      0.80        15
#   Serena Williams       0.71      0.77      0.74        13
#        Tony Blair       0.71      0.56      0.62        36
#
#          accuracy                           0.69       390
#         macro avg       0.76      0.58      0.61       390
#      weighted avg       0.74      0.69      0.68       390

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. 定位John Ashcroft的样本
john_name = 'John Ashcroft'
john_class = np.where(np.array(target_names) == john_name)[0][0]  # 获取类别编号
john_indices = np.where(y == john_class)[0]  # 所有该类别样本的索引

# 2. 随机选择最多5个样本（或全部）
n_samples = min(5, len(john_indices))
selected_indices = np.random.choice(john_indices, size=n_samples, replace=False)

# 3. 创建对比画布
fig, axes = plt.subplots(2, n_samples, figsize=(n_samples*3, 6))
plt.suptitle(f"{john_name} - Original vs Preprocessed", fontsize=14, y=1.05)

# 4. 可视化对比
for j, idx in enumerate(selected_indices):
    # 原始图像（第一行）
    if n_samples > 1:
        ax_orig = axes[0, j]
        ax_proc = axes[1, j]
    else:
        ax_orig = axes[0]
        ax_proc = axes[1]
    
    ax_orig.imshow(lfw_people.images[idx], cmap='gray')
    ax_orig.set_title(f"Original #{j+1}", fontsize=10)
    ax_orig.axis('off')
    
    # 预处理图像（第二行）
    proc_img = X_enhanced[idx].reshape(50, 37) if X_enhanced[idx].ndim == 1 else X_enhanced[idx]
    ax_proc.imshow(proc_img, cmap='gray')
    ax_proc.set_title(f"Preprocessed", fontsize=10)
    ax_proc.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # PCA
# - 选择过少的主成分可能导致严重的信息丢失，影响后续分析或模型性能。
# - 选择过多的主成分则可能削弱降维带来的计算效率提升和噪声过滤优势。
#
# 因此，在实际操作中需要平衡降维效果与信息保留的关系。
# ## 累计方差贡献率法
#
# 用于决定主成分个数。具体步骤如下：
#
# 1. 计算每个主成分的方差贡献率。
# 2. 累加前几个主成分的方差贡献率，直到其达到或超过85、86、87..99%
# 3. 选择让acc最大化的对应的主成分个数作为最终结果。

# %%
def plot_gallery(images, titles, h, w, n_row=3, n_col=4):
    """Helper function to plot a gallery of portraits"""
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=0.01, right=0.99, top=0.90, hspace=0.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

# %%
# 设置方差阈值列表和存储结果的字典
variance_thresholds = np.linspace(0.8, 0.99, 20)
results = {
    'rare': {'n_components': [], 'accuracy': []},
    'ma': {'n_components': [], 'accuracy': []}
}

# 定义评估函数
def evaluate_pca_svm(X_train, X_test, y_train, y_test, dataset_type):
    pca_full = PCA().fit(X_train)
    cumulative_var = np.cumsum(pca_full.explained_variance_ratio_)
    
    for threshold in variance_thresholds:
        # 计算所需主成分数
        n_components = np.argmax(cumulative_var >= threshold) + 1
        results[dataset_type]['n_components'].append(n_components)
        
        # PCA降维
        pca = PCA(n_components=n_components, whiten=True)
        X_train_pca = pca.fit_transform(X_train)
        X_test_pca = pca.transform(X_test)
        
        # 训练SVM并评估
        model = SVC(kernel='rbf', class_weight='balanced')
        model.fit(X_train_pca, y_train)
        pred = model.predict(X_test_pca)
        acc = accuracy_score(y_test, pred)
        results[dataset_type]['accuracy'].append(acc)

# 对rare和ma数据集分别评估
evaluate_pca_svm(X_rare_train, X_rare_test, y_rare_train, y_rare_test, 'rare')
evaluate_pca_svm(X_ma_train, X_ma_test, y_ma_train, y_ma_test, 'ma')

# 可视化结果
plt.figure(figsize=(12, 6))

# 主成分数量对比
plt.subplot(1, 2, 1)
plt.plot(variance_thresholds, results['rare']['n_components'], 'o-', label='Rare Classes')
plt.plot(variance_thresholds, results['ma']['n_components'], 's-', label='MA Classes')
plt.xlabel('Variance Threshold')
plt.ylabel('Number of Components')
plt.title('PCA Components Required')
plt.legend()
plt.grid(True)

# 分类准确度对比
plt.subplot(1, 2, 2)
plt.plot(variance_thresholds, results['rare']['accuracy'], 'o-', label='Rare Classes')
plt.plot(variance_thresholds, results['ma']['accuracy'], 's-', label='MA Classes')
plt.xlabel('Variance Threshold')
plt.ylabel('Classification Accuracy')
plt.title('SVM Performance')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# 打印详细结果
print("Rare Classes Results:")
for i, thresh in enumerate(variance_thresholds):
    print(f"Threshold {thresh:.2f}: {results['rare']['n_components'][i]} components, Accuracy={results['rare']['accuracy'][i]:.4f}")

print("\nMA Classes Results:")
for i, thresh in enumerate(variance_thresholds):
    print(f"Threshold {thresh:.2f}: {results['ma']['n_components'][i]} components, Accuracy={results['ma']['accuracy'][i]:.4f}")

print(f"Max accuracy for rare classes:{ max(results['rare']['accuracy'])},n_components:{results['rare']['n_components'][np.argmax(results['rare']['accuracy'])]}")
print("Max accuracy for ma classes:", max(results['ma']['accuracy']))
print(f"Max accuracy for ma classes:{ max(results['ma']['accuracy'])},n_components:{results['ma']['n_components'][np.argmax(results['ma']['accuracy'])]}")
# Out:
# Rare Classes Results:
# Threshold 0.80: 260 components, Accuracy=0.2084
# Threshold 0.81: 275 components, Accuracy=0.1910
# Threshold 0.82: 291 components, Accuracy=0.1606
# Threshold 0.83: 309 components, Accuracy=0.1548
# Threshold 0.84: 327 components, Accuracy=0.1346
# Threshold 0.85: 347 components, Accuracy=0.1143
# Threshold 0.86: 369 components, Accuracy=0.1085
# Threshold 0.87: 392 components, Accuracy=0.1013
# Threshold 0.88: 418 components, Accuracy=0.0825
# Threshold 0.89: 446 components, Accuracy=0.0825
# Threshold 0.90: 477 components, Accuracy=0.0767
# Threshold 0.91: 512 components, Accuracy=0.0666
# Threshold 0.92: 550 components, Accuracy=0.0651
# Threshold 0.93: 594 components, Accuracy=0.0622
# Threshold 0.94: 644 components, Accuracy=0.0478
# Threshold 0.95: 703 components, Accuracy=0.0463
# Threshold 0.96: 773 components, Accuracy=0.0492
# Threshold 0.97: 860 components, Accuracy=0.0376
# Threshold 0.98: 977 components, Accuracy=0.0260
# Threshold 0.99: 1154 components, Accuracy=0.0159
#
# MA Classes Results:
# Threshold 0.80: 226 components, Accuracy=0.6821
# Threshold 0.81: 238 components, Accuracy=0.6821
# Threshold 0.82: 251 components, Accuracy=0.6718
# Threshold 0.83: 264 components, Accuracy=0.6692
# Threshold 0.84: 279 components, Accuracy=0.6436
# Threshold 0.85: 294 components, Accuracy=0.6615
# Threshold 0.86: 311 components, Accuracy=0.6462
# Threshold 0.87: 329 components, Accuracy=0.6282
# Threshold 0.88: 348 components, Accuracy=0.6282
# Threshold 0.89: 369 components, Accuracy=0.6256
# Threshold 0.90: 392 components, Accuracy=0.6103
# Threshold 0.91: 418 components, Accuracy=0.6051
# Threshold 0.92: 446 components, Accuracy=0.6026
# Threshold 0.93: 478 components, Accuracy=0.5897
# Threshold 0.94: 514 components, Accuracy=0.5667
# Threshold 0.95: 556 components, Accuracy=0.5333
# Threshold 0.96: 605 components, Accuracy=0.5051
# Threshold 0.97: 665 components, Accuracy=0.4692
# Threshold 0.98: 744 components, Accuracy=0.4154
# Threshold 0.99: 861 components, Accuracy=0.3051
# Max accuracy for rare classes:0.20839363241678727,n_components:260
# Max accuracy for ma classes: 0.6820512820512821
# Max accuracy for ma classes:0.6820512820512821,n_components:226

# %% [markdown]
# rare和ma的准确率变化趋势其实差不多，但是到达峰值所需要的主成分数ma总是大于rare。
#
# 在调节主成分数时，Rare（稀有类别）和MA（普通类别）的准确率变化趋势相似但峰值所需主成分数不同，这一现象可以从数据特性和PCA的数学本质来解释。
#
# ### **1. 数据复杂度差异**
#
# #### **(1) 稀有类别（Rare）的特性**
#
# - **样本量少**：每个稀有类别的样本数较少（10-30个），导致：
#   - 数据分布估计不准确，PCA捕获的方差结构可能不稳定
#   - 更易达到"信息饱和"（少量主成分即可捕获主要模式）
# - **特征简单性**：稀有类别的样本可能具有更简单的共同特征（如相似光照/角度）
#
# #### **(2) 普通类别（MA）的特性**
#
# - **样本量大**：每个类别样本更多（>30个），导致：
#   - 类内多样性更高（不同姿态、表情等）
#   - 需要更多主成分才能覆盖这些复杂变化
# - **类别间重叠**：普通类别间可能存在更多特征重叠，需要更高维度的判别信息

# %%
n_components=81
pca=PCA(n_components=n_components,whiten=True).fit(X_rare_train)
#x_all_pca=pca.transform(lfw_people.data)
X_rare_train_pca=pca.fit_transform(X_rare_train)
X_rare_test_pca=pca.transform(X_rare_test)
model = SVC(kernel='rbf', class_weight='balanced')
model.fit(X_rare_train_pca, y_rare_train)
pred = model.predict(X_rare_test_pca)
acc = accuracy_score(y_rare_test, pred)
# 打印分类报告
print("Rare classes accuracy:", acc)
print(f"Final Accuracy with {n_components} components: {acc:.4f}")
print("parameters of svc:",model.get_params())
labels_in_use = np.unique(np.concatenate([y_rare_test, pred]))
target_names_filtered = [lfw_people.target_names[i] for i in labels_in_use]
print(classification_report(y_rare_test, pred,
                            labels=labels_in_use,
                            target_names=target_names_filtered,
                            zero_division=0))
mean_face = pca.mean_.reshape((h, w))
plt.figure(figsize=(4, 4))
plt.imshow(mean_face, cmap='gray')
plt.title("Mean Face")
plt.axis('off')
plt.show()

eigenfaces_rare = pca.components_.reshape((81, h, w))
# Out:
# Rare classes accuracy: 0.35021707670043417
# Final Accuracy with 81 components: 0.3502
# parameters of svc: {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       0.25      0.20      0.22         5
#              Adrien Brody       0.00      0.00      0.00         3
#          Alejandro Toledo       0.31      0.40      0.35        10
#              Alvaro Uribe       0.40      0.22      0.29         9
#           Amelie Mauresmo       0.25      0.60      0.35         5
#              Andre Agassi       0.18      0.22      0.20         9
#              Andy Roddick       0.00      0.00      0.00         4
#            Angelina Jolie       0.29      0.40      0.33         5
#               Ann Veneman       1.00      0.33      0.50         3
#           Anna Kournikova       0.00      0.00      0.00         3
#             Ari Fleischer       0.50      0.33      0.40         3
#     Arnold Schwarzenegger       0.08      0.40      0.13        10
#      Atal Bihari Vajpayee       0.40      0.67      0.50         6
#              Bill Clinton       0.40      0.29      0.33         7
#                Bill Gates       1.00      0.25      0.40         4
#              Bill McBride       0.00      0.00      0.00         3
#                Bill Simon       1.00      0.50      0.67         4
#            Britney Spears       1.00      0.50      0.67         4
#              Carlos Menem       0.25      0.20      0.22         5
#               Carlos Moya       0.00      0.00      0.00         5
#      Catherine Zeta-Jones       0.33      0.33      0.33         3
#             Charles Moose       0.00      0.00      0.00         3
#          Condoleezza Rice       0.00      0.00      0.00         3
#             David Beckham       0.50      0.25      0.33         8
#          David Nalbandian       1.00      0.25      0.40         4
#               Dick Cheney       1.00      0.33      0.50         3
#     Dominique de Villepin       1.00      0.50      0.67         4
#            Edmund Stoiber       0.00      0.00      0.00         3
#           Eduardo Duhalde       0.20      0.33      0.25         3
#              Fidel Castro       0.67      0.40      0.50         5
#            George HW Bush       0.00      0.00      0.00         3
#          George Robertson       0.56      1.00      0.71         5
#   Gloria Macapagal Arroyo       0.59      0.91      0.71        11
# Gonzalo Sanchez de Lozada       0.00      0.00      0.00         3
#              Gordon Brown       0.00      0.00      0.00         3
#                Gray Davis       0.00      0.00      0.00         7
#           Guillermo Coria       0.25      0.57      0.35         7
#               Halle Berry       0.40      0.50      0.44         4
#              Hamid Karzai       0.33      0.60      0.43         5
#                 Hans Blix       0.40      0.40      0.40        10
#             Harrison Ford       0.40      0.67      0.50         3
#           Hillary Clinton       0.50      0.33      0.40         3
#               Howard Dean       0.00      0.00      0.00         3
#                 Hu Jintao       0.75      0.75      0.75         4
#                Ian Thorpe       0.00      0.00      0.00         2
#               Igor Ivanov       0.08      0.20      0.11         5
#                Jack Straw       0.17      0.43      0.24         7
#               Jackie Chan       1.00      0.67      0.80         3
#             Jacques Rogge       0.50      0.33      0.40         3
#               James Blake       0.00      0.00      0.00         4
#               James Kelly       0.00      0.00      0.00         3
#                Jason Kidd       0.00      0.00      0.00         2
#             Javier Solana       0.00      0.00      0.00         2
#              Jean Charest       0.38      0.75      0.50         4
#        Jean-David Levitte       0.25      0.33      0.29         3
#                  Jeb Bush       0.20      0.33      0.25         3
#          Jennifer Aniston       0.50      0.20      0.29         5
#         Jennifer Capriati       0.12      0.50      0.20        10
#           Jennifer Garner       0.33      0.33      0.33         3
#            Jennifer Lopez       1.00      0.60      0.75         5
#         Jeremy Greenstock       0.50      0.50      0.50         6
#               Jiang Zemin       1.00      0.40      0.57         5
#                Jiri Novak       1.00      0.67      0.80         3
#             Joe Lieberman       0.00      0.00      0.00         3
#       John Allen Muhammad       1.00      0.33      0.50         3
#               John Bolton       1.00      0.25      0.40         4
#               John Howard       0.00      0.00      0.00         5
#                John Kerry       0.80      1.00      0.89         4
#           John Negroponte       0.20      0.25      0.22         8
#              John Paul II       1.00      0.33      0.50         3
#                 John Snow       1.00      0.25      0.40         4
#           Joschka Fischer       1.00      0.40      0.57         5
#          Jose Maria Aznar       0.00      0.00      0.00         6
#       Juan Carlos Ferrero       0.43      0.43      0.43         7
#            Julianne Moore       0.25      0.20      0.22         5
#          Julie Gerberding       0.00      0.00      0.00         4
#              Keanu Reeves       0.00      0.00      0.00         3
#             Kim Clijsters       0.67      0.50      0.57         4
#            Kim Ryong-sung       1.00      0.67      0.80         3
#                Kofi Annan       0.71      0.62      0.67         8
#           Lance Armstrong       0.00      0.00      0.00         5
#                Laura Bush       0.67      0.80      0.73        10
#         Lindsay Davenport       0.67      0.80      0.73         5
#            Lleyton Hewitt       0.33      0.50      0.40        10
#           Lucio Gutierrez       0.00      0.00      0.00         3
# Luiz Inacio Lula da Silva       0.50      0.67      0.57        12
#          Mahathir Mohamad       0.00      0.00      0.00         3
#             Mahmoud Abbas       0.57      0.57      0.57         7
#        Mark Philippoussis       1.00      0.33      0.50         3
#     Megawati Sukarnoputri       0.60      0.75      0.67         8
#              Meryl Streep       0.43      0.75      0.55         4
#         Michael Bloomberg       0.12      0.20      0.15         5
#           Michael Jackson       1.00      1.00      1.00         3
#        Michael Schumacher       0.00      0.00      0.00         4
#                 Mike Weir       0.00      0.00      0.00         3
#          Mohammad Khatami       1.00      0.33      0.50         3
#         Mohammed Al-Douri       0.00      0.00      0.00         4
#              Muhammad Ali       0.00      0.00      0.00         3
#              Nancy Pelosi       1.00      0.25      0.40         4
#               Naomi Watts       0.67      0.40      0.50         5
#           Nestor Kirchner       0.31      0.56      0.40         9
#     Nicanor Duarte Frutos       0.00      0.00      0.00         3
#             Nicole Kidman       0.00      0.00      0.00         5
#               Norah Jones       0.50      0.25      0.33         4
#       Paradorn Srichaphan       0.00      0.00      0.00         2
#               Paul Bremer       1.00      0.20      0.33         5
#              Paul Burrell       0.50      0.67      0.57         3
#            Paul Wolfowitz       0.00      0.00      0.00         2
#          Pervez Musharraf       1.00      0.25      0.40         4
#              Pete Sampras       0.67      0.33      0.44         6
#            Pierce Brosnan       0.50      0.50      0.50         4
#        Queen Elizabeth II       0.00      0.00      0.00         3
#      Recep Tayyip Erdogan       0.67      0.29      0.40         7
#           Renee Zellweger       0.20      0.25      0.22         4
#             Ricardo Lagos       0.00      0.00      0.00         7
#          Richard Gephardt       0.00      0.00      0.00         3
#              Richard Gere       0.00      0.00      0.00         2
#             Richard Myers       1.00      0.25      0.40         4
#             Roger Federer       1.00      0.33      0.50         3
#              Roh Moo-hyun       1.00      0.75      0.86         8
#        Rubens Barrichello       0.00      0.00      0.00         3
#          Rudolph Giuliani       0.14      0.29      0.19         7
#            Saddam Hussein       1.00      0.50      0.67         6
#               Salma Hayek       0.00      0.00      0.00         3
#             Sergey Lavrov       0.00      0.00      0.00         3
#    Sergio Vieira De Mello       1.00      0.33      0.50         3
#         Silvio Berlusconi       0.29      0.25      0.27         8
#           Spencer Abraham       0.17      0.50      0.25         4
#       Taha Yassin Ramadan       0.25      0.25      0.25         4
#              Tang Jiaxuan       0.50      0.33      0.40         3
#               Tiger Woods       0.00      0.00      0.00         6
#                Tim Henman       0.33      0.20      0.25         5
#                Tom Cruise       1.00      0.33      0.50         3
#               Tom Daschle       0.75      0.50      0.60         6
#                 Tom Hanks       0.00      0.00      0.00         3
#                 Tom Ridge       0.38      0.62      0.48         8
#              Tommy Franks       0.00      0.00      0.00         4
#            Tommy Thompson       0.00      0.00      0.00         3
#                Trent Lott       0.40      0.50      0.44         4
#            Venus Williams       0.33      0.25      0.29         4
#               Vicente Fox       0.40      0.50      0.44         8
#            Vladimir Putin       0.16      0.42      0.23        12
#            Walter Mondale       0.00      0.00      0.00         3
#                Wen Jiabao       0.50      0.33      0.40         3
#              Winona Ryder       0.44      0.67      0.53         6
#          Yoriko Kawaguchi       1.00      0.33      0.50         3
#
#                  accuracy                           0.35       691
#                 macro avg       0.40      0.30      0.31       691
#              weighted avg       0.41      0.35      0.34       691

# %% [markdown]
# mean 图像非常抽象，没有特征的表达。学到的特征比较简单，也就导致最后得到的较优主成分数比较少

# %%
pca = PCA(n_components=108, whiten=True)
X_ma_train_pca = pca.fit_transform(X_ma_train)
X_ma_test_pca = pca.transform(X_ma_test)

# 训练SVM并评估
model = SVC(kernel='rbf', class_weight='balanced')
model.fit(X_ma_train_pca, y_ma_train)
pred = model.predict(X_ma_test_pca)
acc = accuracy_score(y_ma_test, pred)
# 打印分类报告
labels_in_use = np.unique(np.concatenate([y_ma_test, pred]))
target_names_filtered = [lfw_people.target_names[i] for i in labels_in_use]
print(classification_report(y_ma_test, pred,
                            labels=labels_in_use,
                            target_names=target_names_filtered,
                            zero_division=0))
print("MA classes accuracy:", acc)
print(f"Final Accuracy with n components: {acc:.4f}")
print("parameter of SVC:",model.get_params())

eigenfaces_ma = pca.components_.reshape((108, h, w))
mean_face = pca.mean_.reshape((h, w))
plt.figure(figsize=(4, 4))
plt.imshow(mean_face, cmap='gray')
plt.title("Mean Face")
plt.axis('off')
plt.show()


# 找出距离平均脸最近的训练图像
mean_vector = pca.mean_.reshape(1, -1)         # shape (1, D)
dists = euclidean_distances(X_ma_train, mean_vector).flatten()
closest_idx = np.argmin(dists)
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.93      0.68      0.79        19
#      Colin Powell       0.74      0.88      0.81        59
#   Donald Rumsfeld       0.61      0.83      0.70        30
#     George W Bush       0.85      0.88      0.86       133
# Gerhard Schroeder       0.55      0.78      0.65        27
#       Hugo Chavez       0.65      0.61      0.63        18
#    Jacques Chirac       1.00      0.23      0.38        13
#     Jean Chretien       1.00      0.21      0.35        14
#     John Ashcroft       1.00      0.85      0.92        13
# Junichiro Koizumi       0.77      0.67      0.71        15
#   Serena Williams       1.00      0.46      0.63        13
#        Tony Blair       0.64      0.64      0.64        36
#
#          accuracy                           0.76       390
#         macro avg       0.81      0.64      0.67       390
#      weighted avg       0.79      0.76      0.75       390
#
# MA classes accuracy: 0.7564102564102564
# Final Accuracy with n components: 0.7564
# parameter of SVC: {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %% [markdown]
# mean图像上有更加突出的形状，说明样本量多的话学到的特征也会多。

# %%
eigenface_titles = ["eigenface %d" % i for i in range(eigenfaces_rare.shape[0])]
plot_gallery(eigenfaces_rare, eigenface_titles, h, w)
print("Rare classes eigenfaces:")
eigenface_titles = ["eigenface %d" % i for i in range(eigenfaces_ma.shape[0])]
plot_gallery(eigenfaces_ma, eigenface_titles, h, w)
print("MA classes eigenfaces:")
plt.show()

# diff_pc = np.argmax(np.sum(np.abs(eigenfaces_rare - eigenfaces_ma), axis=(1, 2)))
# plt.imshow(eigenfaces_rare[diff_pc] - eigenfaces_ma[diff_pc], cmap='seismic')
# plt.colorbar()
# plt.title(f'diff max(PC{diff_pc+1})')
# plt.show()
# Out:
# Rare classes eigenfaces:
# MA classes eigenfaces:

# %% [markdown]
# 从特征脸上也能看出问题：一方面maclass学到了更多特征另一方面学到的特征更具体。

# %% [markdown]
# ## 调参 我尽力了

# %%
# 初始参数空间（宽范围）
param_dist_phase1 = {
    'C': uniform(0.01, 100),
    'gamma': uniform(0.001, 1),
    'kernel': ['rbf']
}

best_params = None
best_score = -np.inf

for phase in range(3):  # 3轮递进搜索
    # 动态调整参数范围
    if phase > 0 and best_params:
        param_dist = {
            'C': uniform(best_params['C']/3, best_params['C']*3),
            'gamma': uniform(best_params['gamma']/5, best_params['gamma']*5),
            'kernel': ['rbf']
        }
    else:
        param_dist = param_dist_phase1
    
    model = RandomizedSearchCV(
        SVC(class_weight='balanced'),
        param_distributions=param_dist,
        n_iter=50,  # 每轮30次采样
        cv=KFold(n_splits=5, shuffle=True),
        scoring='accuracy',
        random_state=42 + phase, # 不同阶段的随机种子
        n_jobs=-1,
    )
    model.fit(X_rare_train_pca, y_rare_train)
    
    # 保留最佳参数
    if model.best_score_ > best_score:
        best_score = model.best_score_
        best_params = model.best_params_

    print(f"Phase {phase+1} best: {best_params} (score={best_score:.4f})")
# Out:
# Phase 1 best: {'C': 59.251456886204245, 'gamma': 0.047450412719997725, 'kernel': 'rbf'} (score=0.0492)
# Phase 2 best: {'C': 197.2734638059608, 'gamma': 0.01522413869500799, 'kernel': 'rbf'} (score=0.2899)
# Phase 3 best: {'C': 370.9817463690216, 'gamma': 0.007528254478775982, 'kernel': 'rbf'} (score=0.3295)

# %%
model=SVC(kernel='rbf', class_weight='balanced', C=best_params['C'], gamma=best_params['gamma'])
model.fit(X_rare_train_pca, y_rare_train)
predictions = model.predict(X_rare_test_pca)
labels_in_use = np.unique(np.concatenate([y_rare_test, predictions]))
target_names_filtered = [lfw_people.target_names[i] for i in labels_in_use]
print(classification_report(y_rare_test, predictions,
                            labels=labels_in_use,
                            target_names=target_names_filtered,
                            zero_division=0))
# Out:
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       0.25      0.20      0.22         5
#              Adrien Brody       1.00      0.33      0.50         3
#          Alejandro Toledo       0.33      0.40      0.36        10
#              Alvaro Uribe       0.42      0.56      0.48         9
#           Amelie Mauresmo       0.17      0.40      0.24         5
#              Andre Agassi       0.20      0.22      0.21         9
#              Andy Roddick       0.00      0.00      0.00         4
#            Angelina Jolie       0.25      0.40      0.31         5
#               Ann Veneman       1.00      0.33      0.50         3
#           Anna Kournikova       0.00      0.00      0.00         3
#             Ari Fleischer       0.50      0.33      0.40         3
#     Arnold Schwarzenegger       0.07      0.30      0.12        10
#      Atal Bihari Vajpayee       0.50      0.67      0.57         6
#              Bill Clinton       0.27      0.43      0.33         7
#                Bill Gates       0.50      0.25      0.33         4
#              Bill McBride       0.00      0.00      0.00         3
#                Bill Simon       0.25      0.25      0.25         4
#            Britney Spears       0.50      0.50      0.50         4
#              Carlos Menem       0.25      0.20      0.22         5
#               Carlos Moya       0.00      0.00      0.00         5
#      Catherine Zeta-Jones       0.50      0.33      0.40         3
#             Charles Moose       0.50      0.33      0.40         3
#          Condoleezza Rice       1.00      0.33      0.50         3
#             David Beckham       0.33      0.38      0.35         8
#          David Nalbandian       1.00      0.25      0.40         4
#               Dick Cheney       1.00      0.33      0.50         3
#     Dominique de Villepin       1.00      0.50      0.67         4
#            Edmund Stoiber       0.00      0.00      0.00         3
#           Eduardo Duhalde       0.17      0.33      0.22         3
#              Fidel Castro       0.50      0.40      0.44         5
#            George HW Bush       0.00      0.00      0.00         3
#          George Robertson       0.30      0.60      0.40         5
#   Gloria Macapagal Arroyo       0.59      0.91      0.71        11
# Gonzalo Sanchez de Lozada       0.00      0.00      0.00         3
#              Gordon Brown       0.00      0.00      0.00         3
#                Gray Davis       0.12      0.14      0.13         7
#           Guillermo Coria       0.27      0.57      0.36         7
#               Halle Berry       0.67      0.50      0.57         4
#              Hamid Karzai       0.29      0.40      0.33         5
#                 Hans Blix       0.50      0.50      0.50        10
#             Harrison Ford       0.50      0.67      0.57         3
#           Hillary Clinton       0.50      0.33      0.40         3
#               Howard Dean       0.00      0.00      0.00         3
#                 Hu Jintao       0.75      0.75      0.75         4
#                Ian Thorpe       0.00      0.00      0.00         2
#               Igor Ivanov       0.14      0.20      0.17         5
#                Jack Straw       0.33      0.14      0.20         7
#               Jackie Chan       1.00      0.67      0.80         3
#             Jacques Rogge       0.50      0.33      0.40         3
#               James Blake       0.00      0.00      0.00         4
#               James Kelly       0.00      0.00      0.00         3
#                Jason Kidd       0.00      0.00      0.00         2
#             Javier Solana       0.00      0.00      0.00         2
#              Jean Charest       0.29      0.50      0.36         4
#        Jean-David Levitte       0.00      0.00      0.00         3
#                  Jeb Bush       0.00      0.00      0.00         3
#          Jennifer Aniston       0.33      0.40      0.36         5
#         Jennifer Capriati       0.19      0.50      0.27        10
#           Jennifer Garner       0.00      0.00      0.00         3
#            Jennifer Lopez       0.75      0.60      0.67         5
#         Jeremy Greenstock       1.00      0.33      0.50         6
#               Jiang Zemin       1.00      0.40      0.57         5
#                Jiri Novak       1.00      0.67      0.80         3
#             Joe Lieberman       0.00      0.00      0.00         3
#       John Allen Muhammad       1.00      0.33      0.50         3
#               John Bolton       1.00      0.50      0.67         4
#               John Howard       0.00      0.00      0.00         5
#                John Kerry       0.50      1.00      0.67         4
#           John Negroponte       0.25      0.38      0.30         8
#              John Paul II       0.00      0.00      0.00         3
#                 John Snow       1.00      0.50      0.67         4
#           Joschka Fischer       0.75      0.60      0.67         5
#          Jose Maria Aznar       0.20      0.17      0.18         6
#       Juan Carlos Ferrero       0.33      0.43      0.38         7
#            Julianne Moore       0.33      0.20      0.25         5
#          Julie Gerberding       1.00      0.25      0.40         4
#              Keanu Reeves       0.00      0.00      0.00         3
#             Kim Clijsters       0.40      0.50      0.44         4
#            Kim Ryong-sung       0.67      0.67      0.67         3
#                Kofi Annan       0.83      0.62      0.71         8
#           Lance Armstrong       0.00      0.00      0.00         5
#                Laura Bush       0.50      0.80      0.62        10
#         Lindsay Davenport       0.43      0.60      0.50         5
#            Lleyton Hewitt       0.36      0.40      0.38        10
#           Lucio Gutierrez       0.00      0.00      0.00         3
# Luiz Inacio Lula da Silva       0.61      0.92      0.73        12
#          Mahathir Mohamad       0.00      0.00      0.00         3
#             Mahmoud Abbas       0.50      0.57      0.53         7
#        Mark Philippoussis       0.50      0.33      0.40         3
#     Megawati Sukarnoputri       0.75      0.75      0.75         8
#              Meryl Streep       0.43      0.75      0.55         4
#         Michael Bloomberg       0.00      0.00      0.00         5
#           Michael Jackson       1.00      1.00      1.00         3
#        Michael Schumacher       0.25      0.25      0.25         4
#                 Mike Weir       1.00      0.33      0.50         3
#          Mohammad Khatami       1.00      0.33      0.50         3
#         Mohammed Al-Douri       0.00      0.00      0.00         4
#              Muhammad Ali       0.00      0.00      0.00         3
#              Nancy Pelosi       0.50      0.25      0.33         4
#               Naomi Watts       0.60      0.60      0.60         5
#           Nestor Kirchner       0.33      0.33      0.33         9
#     Nicanor Duarte Frutos       0.00      0.00      0.00         3
#             Nicole Kidman       0.14      0.20      0.17         5
#               Norah Jones       0.50      0.25      0.33         4
#       Paradorn Srichaphan       0.00      0.00      0.00         2
#               Paul Bremer       0.25      0.20      0.22         5
#              Paul Burrell       0.60      1.00      0.75         3
#            Paul Wolfowitz       0.00      0.00      0.00         2
#          Pervez Musharraf       1.00      0.25      0.40         4
#              Pete Sampras       0.67      0.67      0.67         6
#            Pierce Brosnan       0.00      0.00      0.00         4
#        Queen Elizabeth II       0.00      0.00      0.00         3
#      Recep Tayyip Erdogan       0.25      0.43      0.32         7
#           Renee Zellweger       0.50      0.25      0.33         4
#             Ricardo Lagos       0.00      0.00      0.00         7
#          Richard Gephardt       0.00      0.00      0.00         3
#              Richard Gere       0.00      0.00      0.00         2
#             Richard Myers       1.00      0.25      0.40         4
#             Roger Federer       1.00      0.33      0.50         3
#              Roh Moo-hyun       0.78      0.88      0.82         8
#        Rubens Barrichello       0.00      0.00      0.00         3
#          Rudolph Giuliani       0.33      0.29      0.31         7
#            Saddam Hussein       1.00      0.50      0.67         6
#               Salma Hayek       0.00      0.00      0.00         3
#             Sergey Lavrov       1.00      0.67      0.80         3
#    Sergio Vieira De Mello       1.00      0.33      0.50         3
#         Silvio Berlusconi       0.19      0.38      0.25         8
#           Spencer Abraham       0.20      0.25      0.22         4
#       Taha Yassin Ramadan       0.25      0.25      0.25         4
#              Tang Jiaxuan       0.50      0.33      0.40         3
#               Tiger Woods       0.50      0.17      0.25         6
#                Tim Henman       0.25      0.20      0.22         5
#                Tom Cruise       1.00      0.33      0.50         3
#               Tom Daschle       0.33      0.33      0.33         6
#                 Tom Hanks       0.00      0.00      0.00         3
#                 Tom Ridge       0.42      0.62      0.50         8
#              Tommy Franks       0.00      0.00      0.00         4
#            Tommy Thompson       0.00      0.00      0.00         3
#                Trent Lott       0.67      0.50      0.57         4
#            Venus Williams       0.00      0.00      0.00         4
#               Vicente Fox       0.71      0.62      0.67         8
#            Vladimir Putin       0.15      0.50      0.24        12
#            Walter Mondale       0.00      0.00      0.00         3
#                Wen Jiabao       0.50      0.33      0.40         3
#              Winona Ryder       0.40      0.67      0.50         6
#          Yoriko Kawaguchi       0.00      0.00      0.00         3
#
#                  accuracy                           0.36       691
#                 macro avg       0.39      0.31      0.32       691
#              weighted avg       0.40      0.36      0.35       691

# %%
# 初始参数空间（宽范围）
param_dist_phase1 = {
    'C': uniform(100,1000),
    'gamma': uniform(0.001, 0.1),
    'kernel': ['rbf']
}

best_params = None
best_score = -np.inf

for phase in range(3):  # 3轮递进搜索
    # 动态调整参数范围
    if phase > 0 and best_params:
        param_dist = {
            'C': uniform(best_params['C']/3, best_params['C']*3),
            'gamma': uniform(best_params['gamma']/5, best_params['gamma']*5),
            'kernel': ['rbf']
        }
    else:
        param_dist = param_dist_phase1
    
    model = RandomizedSearchCV(
        SVC(class_weight='balanced'),
        param_distributions=param_dist,
        n_iter=50,  # 每轮30次采样
        cv=KFold(n_splits=5, shuffle=True),
        scoring='accuracy',
        random_state=42 + phase, # 不同阶段的随机种子
        n_jobs=-1,
    )
    model.fit(X_rare_train_pca, y_rare_train)
    
    # 保留最佳参数
    if model.best_score_ > best_score:
        best_score = model.best_score_
        best_params = model.best_params_

    print(f"Phase {phase+1} best: {best_params} (score={best_score:.4f})")
# Out:
# Phase 1 best: {'C': 871.2703466859457, 'gamma': 0.008404465173409037, 'kernel': 'rbf'} (score=0.3261)
# Phase 2 best: {'C': 2107.70397866272, 'gamma': 0.0059983835563709766, 'kernel': 'rbf'} (score=0.3333)
# Phase 3 best: {'C': 2107.70397866272, 'gamma': 0.0059983835563709766, 'kernel': 'rbf'} (score=0.3333)

# %%
model=SVC(kernel='rbf', class_weight='balanced', C=best_params['C'], gamma=best_params['gamma'])
model.fit(X_rare_train_pca, y_rare_train)
predictions = model.predict(X_rare_test_pca)
labels_in_use = np.unique(np.concatenate([y_rare_test, predictions]))
target_names_filtered = [lfw_people.target_names[i] for i in labels_in_use]
print(classification_report(y_rare_test, predictions,
                            labels=labels_in_use,
                            target_names=target_names_filtered,
                            zero_division=0))
# Out:
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       0.25      0.20      0.22         5
#              Adrien Brody       1.00      0.33      0.50         3
#          Alejandro Toledo       0.31      0.40      0.35        10
#              Alvaro Uribe       0.50      0.56      0.53         9
#           Amelie Mauresmo       0.17      0.40      0.24         5
#              Andre Agassi       0.20      0.22      0.21         9
#              Andy Roddick       0.00      0.00      0.00         4
#            Angelina Jolie       0.29      0.40      0.33         5
#               Ann Veneman       1.00      0.33      0.50         3
#           Anna Kournikova       0.00      0.00      0.00         3
#             Ari Fleischer       0.50      0.33      0.40         3
#     Arnold Schwarzenegger       0.08      0.30      0.13        10
#      Atal Bihari Vajpayee       0.67      0.67      0.67         6
#              Bill Clinton       0.20      0.29      0.24         7
#                Bill Gates       0.33      0.25      0.29         4
#              Bill McBride       0.00      0.00      0.00         3
#                Bill Simon       0.40      0.50      0.44         4
#            Britney Spears       0.50      0.50      0.50         4
#              Carlos Menem       0.17      0.20      0.18         5
#               Carlos Moya       0.00      0.00      0.00         5
#      Catherine Zeta-Jones       0.50      0.33      0.40         3
#             Charles Moose       0.50      0.33      0.40         3
#          Condoleezza Rice       1.00      0.33      0.50         3
#             David Beckham       0.33      0.38      0.35         8
#          David Nalbandian       1.00      0.25      0.40         4
#               Dick Cheney       1.00      0.33      0.50         3
#     Dominique de Villepin       1.00      0.50      0.67         4
#            Edmund Stoiber       0.00      0.00      0.00         3
#           Eduardo Duhalde       0.17      0.33      0.22         3
#              Fidel Castro       0.50      0.40      0.44         5
#            George HW Bush       0.00      0.00      0.00         3
#          George Robertson       0.33      0.80      0.47         5
#   Gloria Macapagal Arroyo       0.62      0.91      0.74        11
# Gonzalo Sanchez de Lozada       0.00      0.00      0.00         3
#              Gordon Brown       0.00      0.00      0.00         3
#                Gray Davis       0.14      0.14      0.14         7
#           Guillermo Coria       0.27      0.57      0.36         7
#               Halle Berry       0.67      0.50      0.57         4
#              Hamid Karzai       0.33      0.40      0.36         5
#                 Hans Blix       0.50      0.40      0.44        10
#             Harrison Ford       0.67      0.67      0.67         3
#           Hillary Clinton       0.50      0.33      0.40         3
#               Howard Dean       0.00      0.00      0.00         3
#                 Hu Jintao       0.75      0.75      0.75         4
#                Ian Thorpe       0.00      0.00      0.00         2
#               Igor Ivanov       0.12      0.20      0.15         5
#                Jack Straw       0.33      0.14      0.20         7
#               Jackie Chan       0.67      0.67      0.67         3
#             Jacques Rogge       0.50      0.33      0.40         3
#               James Blake       0.00      0.00      0.00         4
#               James Kelly       0.00      0.00      0.00         3
#                Jason Kidd       0.00      0.00      0.00         2
#             Javier Solana       0.00      0.00      0.00         2
#              Jean Charest       0.38      0.75      0.50         4
#        Jean-David Levitte       0.00      0.00      0.00         3
#                  Jeb Bush       0.00      0.00      0.00         3
#          Jennifer Aniston       0.40      0.40      0.40         5
#         Jennifer Capriati       0.22      0.50      0.30        10
#           Jennifer Garner       0.00      0.00      0.00         3
#            Jennifer Lopez       0.60      0.60      0.60         5
#         Jeremy Greenstock       1.00      0.33      0.50         6
#               Jiang Zemin       1.00      0.40      0.57         5
#                Jiri Novak       0.67      0.67      0.67         3
#             Joe Lieberman       0.00      0.00      0.00         3
#       John Allen Muhammad       1.00      0.33      0.50         3
#               John Bolton       1.00      0.50      0.67         4
#               John Howard       1.00      0.20      0.33         5
#                John Kerry       0.50      1.00      0.67         4
#           John Negroponte       0.25      0.38      0.30         8
#              John Paul II       1.00      0.33      0.50         3
#                 John Snow       1.00      0.50      0.67         4
#           Joschka Fischer       0.67      0.40      0.50         5
#          Jose Maria Aznar       0.00      0.00      0.00         6
#       Juan Carlos Ferrero       0.43      0.43      0.43         7
#            Julianne Moore       0.50      0.20      0.29         5
#          Julie Gerberding       1.00      0.25      0.40         4
#              Keanu Reeves       0.00      0.00      0.00         3
#             Kim Clijsters       0.29      0.50      0.36         4
#            Kim Ryong-sung       0.67      0.67      0.67         3
#                Kofi Annan       0.83      0.62      0.71         8
#           Lance Armstrong       0.00      0.00      0.00         5
#                Laura Bush       0.53      0.80      0.64        10
#         Lindsay Davenport       0.38      0.60      0.46         5
#            Lleyton Hewitt       0.36      0.40      0.38        10
#           Lucio Gutierrez       0.00      0.00      0.00         3
# Luiz Inacio Lula da Silva       0.67      0.83      0.74        12
#          Mahathir Mohamad       0.00      0.00      0.00         3
#             Mahmoud Abbas       0.50      0.57      0.53         7
#        Mark Philippoussis       0.50      0.33      0.40         3
#     Megawati Sukarnoputri       0.67      0.75      0.71         8
#              Meryl Streep       0.43      0.75      0.55         4
#         Michael Bloomberg       0.25      0.20      0.22         5
#           Michael Jackson       1.00      1.00      1.00         3
#        Michael Schumacher       0.50      0.25      0.33         4
#                 Mike Weir       1.00      0.33      0.50         3
#          Mohammad Khatami       1.00      0.33      0.50         3
#         Mohammed Al-Douri       0.00      0.00      0.00         4
#              Muhammad Ali       0.00      0.00      0.00         3
#              Nancy Pelosi       0.50      0.25      0.33         4
#               Naomi Watts       0.43      0.60      0.50         5
#           Nestor Kirchner       0.38      0.33      0.35         9
#     Nicanor Duarte Frutos       0.00      0.00      0.00         3
#             Nicole Kidman       0.14      0.20      0.17         5
#               Norah Jones       0.50      0.25      0.33         4
#       Paradorn Srichaphan       1.00      0.50      0.67         2
#               Paul Bremer       0.25      0.20      0.22         5
#              Paul Burrell       0.60      1.00      0.75         3
#            Paul Wolfowitz       0.00      0.00      0.00         2
#          Pervez Musharraf       1.00      0.25      0.40         4
#              Pete Sampras       0.67      0.67      0.67         6
#            Pierce Brosnan       0.00      0.00      0.00         4
#        Queen Elizabeth II       0.00      0.00      0.00         3
#      Recep Tayyip Erdogan       0.23      0.43      0.30         7
#           Renee Zellweger       0.50      0.25      0.33         4
#             Ricardo Lagos       0.00      0.00      0.00         7
#          Richard Gephardt       0.00      0.00      0.00         3
#              Richard Gere       0.00      0.00      0.00         2
#             Richard Myers       1.00      0.25      0.40         4
#             Roger Federer       1.00      0.33      0.50         3
#              Roh Moo-hyun       0.78      0.88      0.82         8
#        Rubens Barrichello       0.00      0.00      0.00         3
#          Rudolph Giuliani       0.33      0.29      0.31         7
#            Saddam Hussein       0.75      0.50      0.60         6
#               Salma Hayek       0.00      0.00      0.00         3
#             Sergey Lavrov       1.00      0.67      0.80         3
#    Sergio Vieira De Mello       1.00      0.67      0.80         3
#         Silvio Berlusconi       0.18      0.38      0.24         8
#           Spencer Abraham       0.20      0.25      0.22         4
#       Taha Yassin Ramadan       0.33      0.25      0.29         4
#              Tang Jiaxuan       0.50      0.33      0.40         3
#               Tiger Woods       0.25      0.17      0.20         6
#                Tim Henman       0.25      0.20      0.22         5
#                Tom Cruise       1.00      0.33      0.50         3
#               Tom Daschle       0.29      0.33      0.31         6
#                 Tom Hanks       0.00      0.00      0.00         3
#                 Tom Ridge       0.36      0.50      0.42         8
#              Tommy Franks       0.00      0.00      0.00         4
#            Tommy Thompson       0.00      0.00      0.00         3
#                Trent Lott       0.67      0.50      0.57         4
#            Venus Williams       0.00      0.00      0.00         4
#               Vicente Fox       0.56      0.62      0.59         8
#            Vladimir Putin       0.18      0.50      0.27        12
#            Walter Mondale       0.00      0.00      0.00         3
#                Wen Jiabao       0.50      0.33      0.40         3
#              Winona Ryder       0.44      0.67      0.53         6
#          Yoriko Kawaguchi       0.00      0.00      0.00         3
#
#                  accuracy                           0.37       691
#                 macro avg       0.40      0.32      0.33       691
#              weighted avg       0.41      0.37      0.36       691

# %%
# 初始参数空间（宽范围）
param_dist_phase1 = {
    'C': uniform(0.01, 100),
    'gamma': uniform(0.001, 1),
    'kernel': ['rbf']
}
best_params = None
best_score = -np.inf

for phase in range(3):  # 3轮递进搜索
    # 动态调整参数范围
    if phase > 0 and best_params:
        param_dist = {
            'C': uniform(best_params['C']/2, best_params['C']*2),
            'gamma': uniform(best_params['gamma']/5, best_params['gamma']*5),
            'kernel': ['rbf']
        }
    else:
        param_dist = param_dist_phase1
    
    search = RandomizedSearchCV(
        SVC(class_weight='balanced'),
        param_distributions=param_dist,
        n_iter=50,  # 每轮30次采样
        cv=KFold(n_splits=5, shuffle=True),
        scoring='accuracy',
        n_jobs=-1,
        random_state=42 + phase  # 不同阶段的随机种子
    )
    search.fit(X_ma_train_pca, y_ma_train)
    
    # 保留最佳参数
    if search.best_score_ > best_score:
        best_score = search.best_score_
        best_params = search.best_params_

    print(f"Phase {phase+1} best: {best_params} (score={best_score:.4f})")
# Out:
# Phase 1 best: {'C': 59.251456886204245, 'gamma': 0.047450412719997725, 'kernel': 'rbf'} (score=0.3427)
# Phase 2 best: {'C': 147.97438056125284, 'gamma': 0.01522413869500799, 'kernel': 'rbf'} (score=0.6111)
# Phase 3 best: {'C': 340.857203912415, 'gamma': 0.004251934498728533, 'kernel': 'rbf'} (score=0.7427)

# %%
model=SVC(kernel='rbf', class_weight='balanced', C=best_params['C'], gamma=best_params['gamma'])
model.fit(X_ma_train_pca, y_ma_train)
predictions = search.predict(X_ma_test_pca)
labels_in_use = np.unique(np.concatenate([y_ma_test, predictions]))
target_names_filtered = [lfw_people.target_names[i] for i in labels_in_use]
print(classification_report(y_ma_test, predictions,
                            labels=labels_in_use,
                            target_names=target_names_filtered,
                            zero_division=0))
acc = accuracy_score(y_ma_test, predictions)
print("MA classes accuracy:", acc)
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       1.00      0.74      0.85        19
#      Colin Powell       0.82      0.80      0.81        59
#   Donald Rumsfeld       0.62      0.83      0.71        30
#     George W Bush       0.78      0.93      0.85       133
# Gerhard Schroeder       0.66      0.78      0.71        27
#       Hugo Chavez       0.64      0.50      0.56        18
#    Jacques Chirac       1.00      0.23      0.38        13
#     Jean Chretien       1.00      0.21      0.35        14
#     John Ashcroft       1.00      0.85      0.92        13
# Junichiro Koizumi       0.85      0.73      0.79        15
#   Serena Williams       0.88      0.54      0.67        13
#        Tony Blair       0.63      0.61      0.62        36
#
#          accuracy                           0.76       390
#         macro avg       0.82      0.65      0.68       390
#      weighted avg       0.78      0.76      0.75       390
#
# MA classes accuracy: 0.7615384615384615

# %% [markdown]
# 发现对其使用这种调参收效甚微,甚至不够好

# %%
# 初始参数空间（宽范围）
param_dist_phase1 = {
    'C': uniform(100, 1000),
    'gamma': uniform(0.001, 0.1),
    'kernel': ['rbf']
}
best_params = None
best_score = -np.inf

for phase in range(3):  # 3轮递进搜索
    # 动态调整参数范围
    if phase > 0 and best_params:
        param_dist = {
            'C': uniform(best_params['C']/2, best_params['C']*2),
            'gamma': uniform(best_params['gamma']/5, best_params['gamma']*5),
            'kernel': ['rbf']
        }
    else:
        param_dist = param_dist_phase1
    
    search = RandomizedSearchCV(
        SVC(class_weight='balanced'),
        param_distributions=param_dist,
        n_iter=50,  # 每轮30次采样
        cv=KFold(n_splits=5, shuffle=True),
        scoring='accuracy',
        n_jobs=-1,
        random_state=42 + phase  # 不同阶段的随机种子
    )
    search.fit(X_ma_train_pca, y_ma_train)
    
    # 保留最佳参数
    if search.best_score_ > best_score:
        best_score = search.best_score_
        best_params = search.best_params_

    print(f"Phase {phase+1} best: {best_params} (score={best_score:.4f})")
# Out:
# Phase 1 best: {'C': 692.4145688620424, 'gamma': 0.0056450412719997725, 'kernel': 'rbf'} (score=0.7333)
# Phase 2 best: {'C': 1309.0247913097423, 'gamma': 0.0040289443816285235, 'kernel': 'rbf'} (score=0.7333)
# Phase 3 best: {'C': 2346.8472987559016, 'gamma': 0.0051132302537576545, 'kernel': 'rbf'} (score=0.7479)

# %%
search=SVC(kernel='rbf', class_weight='balanced', C=best_params['C'], gamma=best_params['gamma'])
search.fit(X_ma_train_pca, y_ma_train)
predictions = search.predict(X_ma_test_pca)
labels_in_use = np.unique(np.concatenate([y_ma_test, predictions]))
target_names_filtered = [lfw_people.target_names[i] for i in labels_in_use]
print(classification_report(y_ma_test, predictions,
                            labels=labels_in_use,
                            target_names=target_names_filtered,
                            zero_division=0))
acc = accuracy_score(y_ma_test, predictions)
print("MA classes accuracy:", acc)
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.93      0.74      0.82        19
#      Colin Powell       0.80      0.80      0.80        59
#   Donald Rumsfeld       0.64      0.83      0.72        30
#     George W Bush       0.76      0.92      0.84       133
# Gerhard Schroeder       0.66      0.78      0.71        27
#       Hugo Chavez       0.62      0.44      0.52        18
#    Jacques Chirac       1.00      0.23      0.38        13
#     Jean Chretien       1.00      0.21      0.35        14
#     John Ashcroft       1.00      0.85      0.92        13
# Junichiro Koizumi       0.83      0.67      0.74        15
#   Serena Williams       1.00      0.54      0.70        13
#        Tony Blair       0.63      0.61      0.62        36
#
#          accuracy                           0.75       390
#         macro avg       0.82      0.64      0.68       390
#      weighted avg       0.78      0.75      0.74       390
#
# MA classes accuracy: 0.7538461538461538

# %% [markdown]
# 继续重复这样的调参没啥效果

# %% [markdown]
# # 画图

# %%
def plot_gallery(images, titles, h, w, n_rows=3, n_cols=5):
    plt.figure(figsize=(1.8 * n_cols, 2.4 * n_rows))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_rows * n_cols):
        plt.subplot(n_rows, n_cols, i + 1)  # 修正：n_rows 和 i+1（整数索引）
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

def title(prediction, true_label, target_names):
    pred_name = target_names[prediction].split(' ')[-1]
    true_name = target_names[true_label].split(' ')[-1]
    return f'predicted: {pred_name}\ntrue:      {true_name}'

# 修正：传入 predictions[i] 和 y_test[i] 作为参数
prediction_titles = [title(predictions[i], y_test[i], target_names) for i in range(len(predictions))]
plot_gallery(X_rare_test, prediction_titles, h, w)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[192], line 17
#      14     return f'predicted: {pred_name}\ntrue:      {true_name}'
#      16 # 修正：传入 predictions[i] 和 y_test[i] 作为参数
# ---> 17 prediction_titles = [title(predictions[i], y_test[i], target_names) for i in range(len(predictions))]
#      18 plot_gallery(X_rare_test, prediction_titles, h, w)
#      19 plt.show()
#
# NameError: name 'y_test' is not defined
